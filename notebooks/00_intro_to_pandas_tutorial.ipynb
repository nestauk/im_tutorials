# %% [markdown]
# # Simple Intro to Pandas
#
# This tutrorial looks at the use of the popular python library Pandas. This is widely used to work with big datasets in ways which one can explore, clean, transformm and wrangle.
#
# **Tutorial Structure**
# - [Preamble](#Preamble)
# - [Import Data](#Import-Data)
#  - [Creating DataFrames](#Creating-DataFrames)
#  - [Read Files](#Read-Files)

# %% [markdown]
# # Preamble

# %%
# %load_ext autoreload
# %autoreload 2
# install im_tutorial package
# !pip install git+https://github.com/nestauk/im_tutorials.git
# Out:
# Collecting git+https://github.com/nestauk/im_tutorials.git
#   Cloning https://github.com/nestauk/im_tutorials.git to /tmp/pip-req-build-ojxt7jkf
#   Running command git clone -q https://github.com/nestauk/im_tutorials.git /tmp/pip-req-build-ojxt7jkf
# Requirement already satisfied (use --upgrade to upgrade): im-tutorials==0.1.0 from git+https://github.com/nestauk/im_tutorials.git in /home/ao95/miniconda3/envs/pyenv_nesta/lib/python3.6/site-packages
# Building wheels for collected packages: im-tutorials
#   Building wheel for im-tutorials (setup.py) ... done
#   Created wheel for im-tutorials: filename=im_tutorials-0.1.0-cp36-none-any.whl size=12596 sha256=612f6025a29aadab48e20c4d891a8ea16f7fbbc22ae7fbbf16456df62b1feac1
#   Stored in directory: /tmp/pip-ephem-wheel-cache-fomt82cv/wheels/47/a3/cb/bdc5f9ba49bcfd2c6864b166a1566eb2f104113bf0c3500330
# Successfully built im-tutorials

# %%
# numpy for mathematical functions
import numpy as np
# pandas for handling tabular data
import pandas as pd
# explained later
from im_tutorials.data import cordis
import matplotlib.pyplot as plt

# %% [markdown]
# # Import Data

# %% [markdown]
# ## Creating DataFrames
#
# There are cases where you may hardcode for hacking-uses. This is one way to create a dataframe from scratch. Also, these will be used in examples throughout this tutorial.

# %%
# useful for hacking
toy_1 = pd.DataFrame(
    {
        'col1' : ['a', 'b', np.nan,'c'],
        'col2' : ['d', 'e', 'f','g'],
        'col3' : [1, 2, 3, np.nan],
        'col4' : [4, 7, 6, 5]}
)

# %%
toy_2= pd.DataFrame(
    {
        'col1': [10,20,30,40], 
        'col2': ['d', 'e', 'f', 'k'], 
        'col3': [5, 6, 7, 8],
        'col4': ['h', 'i', 'j', 'k']
    }
)

# %% [markdown]
# ## Read Files

# %%
#i if working from a local .csv file
df = pd.read_csv('file.csv')

# %%
# maybe use cordis
cordis_projects_df = cordis.h2020_projects()
# Out:
# /home/ao95/miniconda3/envs/pyenv_nesta/lib/python3.6/site-packages/smart_open/smart_open_lib.py:398: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL

# %% [markdown]
# # A Look at the Data
# <br/>
# It is almost protocol to look at what's inside your dataset before you start to answer questions. Pandas allows us to easily explore and draw up basic analysis using some of the libraries methods and functions.

# %% [markdown]
# ## DataFrame Structure
#
# Before we start, it is import to note that Pandas deals with two types of data structures: the one-dimensional `Series` and the two-dimensional `DataFrame` In this tutprial, we will mainly work with dataframes.
#
# <img src="../reports/figures/base_01_pandas_5_0.png">

# %% [markdown]
# **Head & Tail**
# <br/>Sometimes, we want a peek at what is going inside. The functions `.head()` and `.tail()` displays the top n rows or last n rows, respectively. Here, `n = 5` rows by default. You can adjust the number of rows by simply changing the number.

# %%
cordis_projects_df.head(n=3)

# %%
cordis_projects_df.tail(n=3)

# %% [markdown]
# **Indexes & Columns**
# <br/>As seen above, dataframes are a tabilar data structire consiting of rows and columns. Indexes are used to identifyu rows whislt columns are identified by the column names. Both are appendable.

# %%
cordis_projects_df.index

# %%
cordis_projects_df.columns

# %% [markdown]
# **Axis 0 or 1?**
# <br/>There are cases where you may want to apply some calculations across rows or columns. This can be appoached by using the `axis` of the dataframe. This can be accessed using the `axis` parameter found in many methods (many are `axis = 0` but default). A few examples will be shown throughout this tutorial.
# - Axis 0- apply on all rows across each column
# - Axis 1- apply on all columns across each row
#
# <img src="../reports/figures/axis.png">

# %% [markdown]
# **DataTypes**
# <br/>It's possible to check what datatypes are in each field.
# <br/> __Note__: Pandas tend to assign a column's datatype as `object` when non-numerical exists inside the field.

# %%
cordis_projects_df.dtypes

# %% [markdown]
# **Selecting**
# <br/> Can select rows and columns

# %%
#can look at columns separtely 
cordis_projects_df['subjects']

# %%
#list of columns
cordis_projects_df[['status', 'coordinatorCountry']]

# %%
#selecting rows
cordis_projects_df[cordis_projects_df.index == 0]
# Out:
#       rcn      id     acronym  status                             programme  \
# 0  218249  822106  WeldGalaxy  SIGNED  [H2020-EU.2.1.3., H2020-EU.2.1.5.1.]
#
#             topics frameworkProgramme  \
# 0  DT-NMBP-20-2018              H2020
#
#                                                title  startDate    endDate  \
# 0  Digital Dynamic Knowledge Platform for Welding... 2018-10-01 2022-03-31
#
#     ...   fundingScheme  coordinator  coordinatorCountry  \
# 0   ...           IA-LS  TWI LIMITED                  UK
#
#                                         participants  \
# 0  [LULEA TEKNISKA UNIVERSITET, ROMSOFT SRL, TECH...
#
#                participantCountries subjects  \
# 0  [SE, RO, UK, NO, PL, FR, IL, ES]      NaN
#
#                                        organisations  \
# 0  [TWI LIMITED, LULEA TEKNISKA UNIVERSITET, ROMS...
#
#                               countries startYear endYear
# 0  [UK, SE, RO, UK, NO, PL, FR, IL, ES]    2018.0  2022.0
#
# [1 rows x 25 columns]

# %%
cordis_projects_df['topics'].value_counts()

# %%
cordis_projects_df.shape

# %% [markdown]
# ## Maths & Statistics
# <br/>
# Many

# %% [markdown]
# ### Arithmetic

# %% [markdown]
# Here, we will use the toy example dataframes to show the operations at work.

# %%
toy_1

# %%
toy_2

# %% [markdown]
# **Addition, Subtraction & More**
#
# Although can use the standard pythonic way, Pandas provides functions to do the exact same job. <br/>
# Note: the columns are chosen since both consist of integers.

# %%
#pythonic way 
toy_1['col4'] + toy_2['col1']

# %%
#pandas fucntion 
toy_1['col4'].add(toy_2['col1'])

# %% [markdown]
# **_Task_**
# <br/>Try the arithmetic functions `subtract()`, `multiply()`, `divide()`, `floordiv()`, `mod()`, `pow()`

# %%
# write code here

# %% [markdown]
# **_Task_**
# <br/>Try the equivalent pythonic way of the above functions (`-`, `*`, `/`, `//`, `%`, `**`)

# %%
# write code here

# %% [markdown]
# **Additional Functions**

# %%
#addition of elements across all rows (deafult axis = 0)
toy_1.sum()

# %%
#addition of element across all columns
toy_1.sum(axis=1)

# %%
# count of number of elements present in columns
cordis_projects_df.count()

# %%
# remember, you can find the result for a single column
cordis_projects_df['projectUrl'].count()

# %% [markdown]
# ### Statistics

# %%
# only on numerical columns
cordis_projects_df.describe()

# %% [markdown]
# **CAUTION!** <br/>
# Use these functions with caution. Some fields are includ data such as IDs or serial numbers but are taken into account when drawing up analysis. It's up to the user to carefully decipher what makes sense.

# %%
#or can separately get this results
df.mean()

# %% [markdown]
# **_Task_**
# <br/>Now try other methods such as `min()`, `max()`, `median()`, `var()`, `std()` and  `quantile()`.

# %%
# write code here

# %% [markdown]
# # Filtering & Subsets

# %% [markdown]
# There are multiple ways to create subsets of an existing dataframes. We can either use the `iloc` & `loc` conventions or directly using a boolean condition as an index.

# %%
# getting the subset of where the condition is true 
cordis_projects_df[cordis_projects_df['coordinatorCountry'] == 'UK'].head()

# %%
#instead of this, can use .loc 

cordis_projects_df.loc[cordis_projects_df['coordinatorCountry'] == 'UK',:].head()

# %% [markdown]
# _Difference between `loc` and `iloc`_
# <br/>Both functions can be used to create subsets. However, there are difference between the two.
# <br/>
# `loc`- Goes up to index n based on the label of the index
# <br/>
# `iloc` Goes up to n index based on position of the indexes.

# %%
#up to top 4 rows (shows rows 0,1,2,3)
cordis_projects_df.iloc[:4]

# %%
#up to index '4' (shows rows 0,1,2,3,4)
cordis_projects_df.loc[:4]
# Out:
#       rcn      id     acronym  status  \
# 0  218249  822106  WeldGalaxy  SIGNED
# 1  218272  822064   MARKET4.0  SIGNED
# 2  216937  816551      SCOPIO  SIGNED
# 3  218836  811181  MapProdIGI  SIGNED
# 4  218837  814729  SSH Impact  SIGNED
#
#                                      programme                 topics  \
# 0         [H2020-EU.2.1.3., H2020-EU.2.1.5.1.]        DT-NMBP-20-2018
# 1         [H2020-EU.2.1.3., H2020-EU.2.1.5.1.]        DT-NMBP-20-2018
# 2  [H2020-EU.3., H2020-EU.2.3., H2020-EU.2.1.]  EIC-SMEInst-2018-2020
# 3                          [H2020-EU.3.6.2.1.]     IBA-SC6-Nexus-2017
# 4                          [H2020-EU.3.6.2.1.]   IBA-SC6-AUSTRIA-2018
#
#   frameworkProgramme                                              title  \
# 0              H2020  Digital Dynamic Knowledge Platform for Welding...
# 1              H2020  A Multi-Sided Business Platform for Plug and P...
# 2              H2020  High-resolution, all-digital microscope that a...
# 3              H2020  Microdata analysis for Policies for Productivi...
# 4              H2020  Conference on the âImpact of Social Sciences...
#
#    startDate    endDate   ...   fundingScheme  \
# 0 2018-10-01 2022-03-31   ...           IA-LS
# 1 2018-11-01 2022-04-30   ...           IA-LS
# 2 2018-05-01 2018-08-31   ...           SME-1
# 3 2018-07-01 2021-06-30   ...             CSA
# 4 2018-03-01 2019-02-28   ...             CSA
#
#                                          coordinator  coordinatorCountry  \
# 0                                        TWI LIMITED                  UK
# 1                         INTRASOFT INTERNATIONAL SA                  BE
# 2                                    SCOPIO LABS LTD                  IL
# 3  ORGANISATION FOR ECONOMIC CO-OPERATION AND DEV...                  FR
# 4                ZENTRUM FUR SOZIALE INNOVATION GMBH                  AT
#
#                                         participants  \
# 0  [LULEA TEKNISKA UNIVERSITET, ROMSOFT SRL, TECH...
# 1  [N.BAZIGOS ABEE, NEDERLANDSE ORGANISATIE VOOR ...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                    participantCountries subjects  \
# 0      [SE, RO, UK, NO, PL, FR, IL, ES]      NaN
# 1  [EL, NL, ES, DE, IT, FR, AT, LU, LT]      NaN
# 2                                   NaN      NaN
# 3                                   NaN      NaN
# 4                                   NaN      NaN
#
#                                        organisations  \
# 0  [TWI LIMITED, LULEA TEKNISKA UNIVERSITET, ROMS...
# 1  [INTRASOFT INTERNATIONAL SA, N.BAZIGOS ABEE, N...
# 2                                  [SCOPIO LABS LTD]
# 3  [ORGANISATION FOR ECONOMIC CO-OPERATION AND DE...
# 4              [ZENTRUM FUR SOZIALE INNOVATION GMBH]
#
#                                   countries startYear endYear
# 0      [UK, SE, RO, UK, NO, PL, FR, IL, ES]    2018.0  2022.0
# 1  [BE, EL, NL, ES, DE, IT, FR, AT, LU, LT]    2018.0  2022.0
# 2                                      [IL]    2018.0  2018.0
# 3                                      [FR]    2018.0  2021.0
# 4                                      [AT]    2018.0  2019.0
#
# [5 rows x 25 columns]

# %%
#4th and 7th in position
cordis_projects_df.iloc[[4,7]]
# Out:
#       rcn      id     acronym  status  \
# 4  218837  814729  SSH Impact  SIGNED
# 7  217626  815751        SIWI  SIGNED
#
#                                      programme                 topics  \
# 4                          [H2020-EU.3.6.2.1.]   IBA-SC6-AUSTRIA-2018
# 7  [H2020-EU.3., H2020-EU.2.3., H2020-EU.2.1.]  EIC-SMEInst-2018-2020
#
#   frameworkProgramme                                              title  \
# 4              H2020  Conference on the âImpact of Social Sciences...
# 7              H2020  Automatic Hitching for total Safety of Farmers...
#
#    startDate    endDate   ...   fundingScheme  \
# 4 2018-03-01 2019-02-28   ...             CSA
# 7 2018-05-01 2018-08-31   ...           SME-1
#
#                            coordinator  coordinatorCountry  participants  \
# 4  ZENTRUM FUR SOZIALE INNOVATION GMBH                  AT           NaN
# 7                    SIWI MASKINER APS                  DK           NaN
#
#   participantCountries subjects                          organisations  \
# 4                  NaN      NaN  [ZENTRUM FUR SOZIALE INNOVATION GMBH]
# 7                  NaN      NaN                    [SIWI MASKINER APS]
#
#   countries startYear endYear
# 4      [AT]    2018.0  2019.0
# 7      [DK]    2018.0  2018.0
#
# [2 rows x 25 columns]

# %% [markdown]
# # Data Wrangling

# %% [markdown]
# ## Cleaning

# %% [markdown]
# **Dropping Data**
# <br/>

# %%
# drop columns (a list of column names or single!)
toy_1.drop(['col1'], axis=1)
# Out:
#   col2  col3  col4
# 0    d   1.0     4
# 1    e   2.0     5
# 2    f   3.0     6
# 3    g   NaN     7

# %%
# drop rows 
toy_1.drop([1,2], axis=0) #inplace=True,
# Out:
#   col1 col2  col3  col4
# 0    a    d   1.0     4
# 3    c    g   NaN     7

# %% [markdown]
# Can also drop rows by setting a field as the index column and droppping the "UK" indices.

# %%
cord_2 = cordis_projects_df.set_index('coordinatorCountry')
cord_2.drop("UK", axis =0)
# Out:
#                        rcn      id            acronym      status  \
# coordinatorCountry
# BE                  218272  822064          MARKET4.0      SIGNED
# IL                  216937  816551             SCOPIO      SIGNED
# FR                  218836  811181         MapProdIGI      SIGNED
# AT                  218837  814729         SSH Impact      SIGNED
# BE                  218833  811163             GLORIA      SIGNED
# SE                  217710  816708           Biopsy X      SIGNED
# DK                  217626  815751               SIWI      SIGNED
# ES                  211066  761508             5GCITY      SIGNED
# ES                  215832  801051              EPEEC      SIGNED
# CH                  212274  749527             MoThal  TERMINATED
# NL                  213720  809174            FITT-iN      SIGNED
# ES                  212504  783988          TheMotion      SIGNED
# FI                  211340  778089       Smartscope-X      SIGNED
# DE                  211977  778788        Hi-ThermCap      SIGNED
# NL                  212163  783989         WATER4AGRI      SIGNED
# ES                  211755  778764         SIADE SaaS      SIGNED
# IT                  211536  778161          Uno-sport      SIGNED
# FR                  211070  761557             NGPaaS      SIGNED
# IL                  211469  777770         HOMEBIOGAS      SIGNED
# ES                  211063  761493            5GTANGO      SIGNED
# ES                  211342  768398     SocialDiabetes      SIGNED
# ES                  211470  777900          CleanPack      SIGNED
# ES                  211132  767609       SMART BIKING      SIGNED
# FI                  208830  739638          WILDBERRY      SIGNED
# ES                  210040  739754     MyTherapyTools  TERMINATED
# FI                  208465  724508         RESISTANCE      SIGNED
# ES                  207704  738110           TR4EMACS      SIGNED
# CY                  208420  739551           KIOS CoE      SIGNED
# NL                  208365  747555            MACOLAB  TERMINATED
# FR                  207191  731086              AMICI      SIGNED
# ...                    ...     ...                ...         ...
# IL                  205181  681507     BeyondtheElite      SIGNED
# IE                  205177  679173            FAT NKT      SIGNED
# ES                  212604  742705          TRANSGANG      SIGNED
# FR                  212584  730976         IBISBA 1.0      SIGNED
# DE                  212596  741409                EEC      SIGNED
# FR                  205175  676943               SLAB      SIGNED
# BE                  212591  731623           IMMUNISA      SIGNED
# HU                  193202  633281  FAWORIT 2014-2015      SIGNED
# IE                  211516  779071             SwiftC      SIGNED
# FR                  212636  749591           MECODIHR      SIGNED
# NL                  193181  633172            EuroMix      SIGNED
# IE                  193204  633292   DiscoverResearch      SIGNED
# FI                  205176  678889          CLIMASLOW      SIGNED
# NL                  204713  679614            BROKERS      SIGNED
# FI                  204704  678578              HRMEG      SIGNED
# DE                  200701  677650               ARCA      SIGNED
# NL                  200699  677576            HARVEST      SIGNED
# ES                  210044  740477             SAURON      SIGNED
# ES                  205172  675324             ENRICH      SIGNED
# DE                  205187  682512            OXYFLUX      SIGNED
# FR                  205185  681978           Brain3.0      SIGNED
# ES                  205178  680200        MYELOMANEXT      SIGNED
# FR                  205169  653718               ENOS      SIGNED
# NO                  205196  693124              ONOFF      SIGNED
# FR                  214359  772103           BRIDGING      SIGNED
# FR                  214317  798326           AXO-MATH      SIGNED
# CH                  205180  681295            BactInd      SIGNED
# AT                  205207  695136       Secret-Cells      SIGNED
# NL                  205186  682022            MEDIATE      SIGNED
# NL                  205195  693039        Sphingolead      SIGNED
#
#                                                             programme  \
# coordinatorCountry
# BE                               [H2020-EU.2.1.3., H2020-EU.2.1.5.1.]
# IL                        [H2020-EU.3., H2020-EU.2.3., H2020-EU.2.1.]
# FR                                                [H2020-EU.3.6.2.1.]
# AT                                                [H2020-EU.3.6.2.1.]
# BE                                                [H2020-EU.3.6.2.1.]
# SE                        [H2020-EU.3., H2020-EU.2.3., H2020-EU.2.1.]
# DK                        [H2020-EU.3., H2020-EU.2.3., H2020-EU.2.1.]
# ES                                                  [H2020-EU.2.1.1.]
# ES                                                  [H2020-EU.1.2.2.]
# CH                                                  [H2020-EU.1.3.2.]
# NL                                 [H2020-EU.2.1.1., H2020-EU.2.3.1.]
# ES                                 [H2020-EU.2.1.1., H2020-EU.2.3.1.]
# FI                  [H2020-EU.3.1.4., H2020-EU.2.1.1., H2020-EU.2....
# DE                  [H2020-EU.3.3., H2020-EU.2.1.1., H2020-EU.2.3.1.]
# NL                                 [H2020-EU.2.1.6., H2020-EU.2.3.1.]
# ES                  [H2020-EU.3.4., H2020-EU.2.1.1., H2020-EU.2.3.1.]
# IT                                 [H2020-EU.2.1.1., H2020-EU.2.3.1.]
# FR                                                  [H2020-EU.2.1.1.]
# IL                                   [H2020-EU.3.5., H2020-EU.2.3.1.]
# ES                                                  [H2020-EU.2.1.1.]
# ES                  [H2020-EU.3.1.4., H2020-EU.2.1.1., H2020-EU.2....
# ES                  [H2020-EU.3.2.4., H2020-EU.3.2.1., H2020-EU.2....
# ES                  [H2020-EU.3.4., H2020-EU.2.1.1., H2020-EU.2.3.1.]
# FI                                                [H2020-EU.2.3.2.2.]
# ES                                                [H2020-EU.2.3.2.2.]
# FI                                                    [H2020-EU.1.1.]
# ES                                                [H2020-EU.3.4.5.4.]
# CY                                                    [H2020-EU.4.a.]
# NL                                                  [H2020-EU.1.3.2.]
# FR                                                [H2020-EU.1.4.2.1.]
# ...                                                               ...
# IL                                                    [H2020-EU.1.1.]
# IE                                                    [H2020-EU.1.1.]
# ES                                                    [H2020-EU.1.1.]
# FR                                                [H2020-EU.1.4.1.2.]
# DE                                                    [H2020-EU.1.1.]
# FR                                                    [H2020-EU.1.1.]
# BE                                                  [H2020-EU.3.1.3.]
# HU                                                  [H2020-EU.1.3.5.]
# IE                                   [H2020-EU.3.6., H2020-EU.2.3.1.]
# FR                                                  [H2020-EU.1.3.2.]
# NL                                                    [H2020-EU.3.2.]
# IE                                                  [H2020-EU.1.3.5.]
# FI                                                    [H2020-EU.1.1.]
# NL                                                    [H2020-EU.1.1.]
# FI                                                    [H2020-EU.1.1.]
# DE                                                    [H2020-EU.1.1.]
# NL                                                    [H2020-EU.1.1.]
# ES                                 [H2020-EU.3.7.4., H2020-EU.3.7.2.]
# ES                                                  [H2020-EU.1.3.1.]
# DE                                                    [H2020-EU.1.1.]
# FR                                                    [H2020-EU.1.1.]
# ES                                                    [H2020-EU.1.1.]
# FR                                                [H2020-EU.3.3.2.3.]
# NO                                                    [H2020-EU.1.1.]
# FR                                                    [H2020-EU.1.1.]
# FR                                                  [H2020-EU.1.3.2.]
# CH                                                    [H2020-EU.1.1.]
# AT                                                    [H2020-EU.1.1.]
# NL                                                    [H2020-EU.1.1.]
# NL                                                    [H2020-EU.1.1.]
#
#                                           topics frameworkProgramme  \
# coordinatorCountry
# BE                               DT-NMBP-20-2018              H2020
# IL                         EIC-SMEInst-2018-2020              H2020
# FR                            IBA-SC6-Nexus-2017              H2020
# AT                          IBA-SC6-AUSTRIA-2018              H2020
# BE                       IBA-SC6-Industrial-2017              H2020
# SE                         EIC-SMEInst-2018-2020              H2020
# DK                         EIC-SMEInst-2018-2020              H2020
# ES                                   ICT-08-2017              H2020
# ES                                FETHPC-02-2017              H2020
# CH                                  MSCA-IF-2016              H2020
# NL                          SMEInst-01-2016-2017              H2020
# ES                          SMEInst-01-2016-2017              H2020
# FI                          SMEInst-06-2016-2017              H2020
# DE                          SMEInst-09-2016-2017              H2020
# NL                          SMEInst-04-2016-2017              H2020
# ES                          SMEInst-10-2016-2017              H2020
# IT                          SMEInst-01-2016-2017              H2020
# FR                                   ICT-08-2017              H2020
# IL                          SMEInst-11-2016-2017              H2020
# ES                                   ICT-08-2017              H2020
# ES                          SMEInst-06-2016-2017              H2020
# ES                          SMEInst-07-2016-2017              H2020
# ES                          SMEInst-10-2016-2017              H2020
# FI                               INNOSUP-02-2016              H2020
# ES                               INNOSUP-02-2016              H2020
# FI                                  ERC-2016-COG              H2020
# ES                  JTI-CS2-2016-CFP03-AIR-02-17              H2020
# CY                       WIDESPREAD-01-2016-2017              H2020
# NL                                  MSCA-IF-2016              H2020
# FR                            INFRAINNOV-02-2016              H2020
# ...                                          ...                ...
# IL                                  ERC-CoG-2015              H2020
# IE                                  ERC-StG-2015              H2020
# ES                                  ERC-2016-ADG              H2020
# FR                               INFRAIA-02-2017              H2020
# DE                                  ERC-2016-ADG              H2020
# FR                                  ERC-StG-2015              H2020
# BE                                SC1-PM-09-2016              H2020
# HU                               MSCA-NIGHT-2014              H2020
# IE                          SMEInst-12-2016-2017              H2020
# FR                                  MSCA-IF-2016              H2020
# NL                                   SFS-12-2014              H2020
# IE                               MSCA-NIGHT-2014              H2020
# FI                                  ERC-StG-2015              H2020
# NL                                  ERC-StG-2015              H2020
# FI                                  ERC-StG-2015              H2020
# DE                                  ERC-StG-2015              H2020
# NL                                  ERC-StG-2015              H2020
# ES                              CIP-01-2016-2017              H2020
# ES                             MSCA-ITN-2015-ETN              H2020
# DE                                  ERC-CoG-2015              H2020
# FR                                  ERC-CoG-2015              H2020
# ES                                  ERC-StG-2015              H2020
# FR                                   LCE-15-2015              H2020
# NO                                  ERC-ADG-2015              H2020
# FR                                  ERC-2017-COG              H2020
# FR                                  MSCA-IF-2017              H2020
# CH                                  ERC-CoG-2015              H2020
# AT                                  ERC-ADG-2015              H2020
# NL                                  ERC-CoG-2015              H2020
# NL                                  ERC-PoC-2015              H2020
#
#                                                                 title  \
# coordinatorCountry
# BE                  A Multi-Sided Business Platform for Plug and P...
# IL                  High-resolution, all-digital microscope that a...
# FR                  Microdata analysis for Policies for Productivi...
# AT                  Conference on the âImpact of Social Sciences...
# BE                   Global Industrial Research & Innovation Analyses
# SE                  EndodrillÂ® Model X - a new endoscopic biopsy ...
# DK                  Automatic Hitching for total Safety of Farmers...
# ES                                                             5GCITY
# ES                  European joint Effort toward a Highly Producti...
# CH                  Functional exploration of the contributions of...
# NL                  Fast IoT market take-up through The Things Net...
# ES                  The most cost-efficient video ad creation plat...
# FI                  Affordable, accessible and automatic screening...
# DE                  High-capacity and high-performance Thermal ene...
# NL                  Securing water for food and safety with the wo...
# ES                  SIADE SaaS: Spatial Decision Support System fo...
# IT                  Delivering contextual information in a hands-f...
# FR                              Next Generation Platform as a Service
# IL                   Turning food industry's organic wastw into value
# ES                  5G Development and validation platform for glo...
# ES                                      Hack your Diabetes Experience
# ES                  UltraCLEAN thermoforming equipment for food PA...
# ES                                   Safe parking system for bicycles
# FI                  Novel application targets and products derived...
# ES                  SME Innovation Associate: matching MyTherapyTo...
# FI                  Resistance evolution in response to spatially ...
# ES                  Flexible Test Rig of Aircraft Control Surfaces...
# CY                  KIOS Research and Innovation Centre of Excellence
# NL                  Towards a mathematical conjecture for the Land...
# FR                  Accelerator and Magnet Infrastructure for Coop...
# ...                                                               ...
# IL                  Beyond the Elite: Jewish Daily Life in Medieva...
# IE                  Targeting iNKT cell and adipocyte crosstalk fo...
# ES                  Transnational Gangs as Agents of Mediation: Ex...
# FR                  Industrial Biotechnology Innovation and Synthe...
# DE                  Economic Engineering of Cooperation in Modern ...
# FR                  Signal processing and Learning Applied to Brai...
# BE                  A Next Generation Immunotherapy for Human Papi...
# HU                  Looking over the Horizon - horizontal prioriti...
# IE                  A technology marketplace for hospitality compl...
# FR                  MEchanisms of Coupling of Ocean Dynamics and I...
# NL                                                            EuroMix
# IE                  Discover Research Dublin - European Researcher...
# FI                  Slowing Down Climate Change: Combining Climate...
# NL                  Participatory Urban Governance between Democra...
# FI                  HRMEG: High-resolution magnetoencephalography:...
# DE                  Analysis and Representation of Complex Activit...
# NL                  Plant foods in human evolution: Factors affect...
# ES                  Scalable multidimensionAl sitUation awaReness ...
# ES                         Enriched communication across the lifespan
# DE                  Oxygen flux measurements as a new tracer for t...
# FR                  Invasive cognitive brain computer interfaces t...
# ES                  Integrated next-generation flow cytometry and ...
# FR                             ENabling Onshore CO2 Storage in Europe
# NO                  Perception of voices that do not exist: Tracki...
# FR                  The function of membrane tethering in plant in...
# FR                  Imaging and analyzing dynamics of reward-relat...
# CH                  Bacterial cooperation at the individual cell l...
# AT                  Cellular diversity and stress-induced cell-sta...
# NL                  Middlebrow Enlightenment: Disseminating Ideas,...
# NL                  Development of a potent dual GCS/GBA2 inhibito...
#
#                     startDate    endDate   ...     \
# coordinatorCountry                         ...
# BE                 2018-11-01 2022-04-30   ...
# IL                 2018-05-01 2018-08-31   ...
# FR                 2018-07-01 2021-06-30   ...
# AT                 2018-03-01 2019-02-28   ...
# BE                 2018-06-01 2020-11-30   ...
# SE                 2018-03-01 2018-08-31   ...
# DK                 2018-05-01 2018-08-31   ...
# ES                 2017-06-01 2019-11-30   ...
# ES                 2018-10-01 2021-09-30   ...
# CH                 2018-01-01 2019-12-31   ...
# NL                 2018-02-01 2018-07-31   ...
# ES                 2017-10-01 2019-03-31   ...
# FI                 2017-08-01 2019-07-31   ...
# DE                 2017-08-01 2019-07-31   ...
# NL                 2017-10-01 2019-03-31   ...
# ES                 2017-09-01 2019-08-31   ...
# IT                 2017-09-01 2019-08-31   ...
# FR                 2017-06-01 2019-05-31   ...
# IL                 2017-08-01 2019-07-31   ...
# ES                 2017-06-01 2019-11-30   ...
# ES                 2017-07-01 2019-06-30   ...
# ES                 2017-08-01 2019-07-31   ...
# ES                 2017-07-01 2019-06-30   ...
# FI                 2017-09-01 2018-08-31   ...
# ES                 2018-03-01 2019-02-28   ...
# FI                 2017-03-01 2022-02-28   ...
# ES                 2017-06-01 2020-11-30   ...
# CY                 2017-03-01 2024-02-29   ...
# NL                 2017-08-01 2019-07-31   ...
# FR                 2017-01-01 2019-06-30   ...
# ...                       ...        ...   ...
# IL                 2016-11-01 2021-10-31   ...
# IE                 2016-09-01 2021-08-31   ...
# ES                 2018-01-01 2022-12-31   ...
# FR                 2017-12-01 2021-11-30   ...
# DE                 2018-03-01 2023-02-28   ...
# FR                 2016-09-01 2021-08-31   ...
# BE                 2017-12-01 2022-11-30   ...
# HU                 2014-05-01 2015-11-30   ...
# IE                 2017-09-01 2019-08-31   ...
# FR                 2018-10-01 2021-09-30   ...
# NL                 2015-05-15 2019-05-14   ...
# IE                 2014-06-01 2015-11-30   ...
# FI                 2017-01-01 2021-12-31   ...
# NL                 2016-08-01 2021-07-31   ...
# FI                 2016-09-01 2021-08-31   ...
# DE                 2016-06-01 2021-05-31   ...
# NL                 2017-02-01 2022-01-31   ...
# ES                 2017-05-01 2020-04-30   ...
# ES                 2016-10-01 2020-09-30   ...
# DE                 2016-10-01 2021-09-30   ...
# FR                 2016-10-01 2021-09-30   ...
# ES                 2016-09-01 2021-08-31   ...
# FR                 2016-09-01 2020-08-31   ...
# NO                 2016-09-01 2021-08-31   ...
# FR                 2018-06-01 2023-05-31   ...
# FR                 2018-05-01 2020-04-30   ...
# CH                 2016-09-01 2021-08-31   ...
# AT                 2016-09-01 2021-08-31   ...
# NL                 2016-09-01 2021-08-31   ...
# NL                 2016-09-01 2018-02-28   ...
#
#                                                            call  \
# coordinatorCountry
# BE                                         H2020-NMBP-PLUG-2018
# IL                                    H2020-SMEInst-2018-2020-1
# FR                                     H2020-IBA-SC6-Nexus-2017
# AT                                   H2020-IBA-SC6-AUSTRIA-2018
# BE                                H2020-IBA-SC6-Industrial-2017
# SE                                    H2020-SMEInst-2018-2020-1
# DK                                    H2020-SMEInst-2018-2020-1
# ES                                             H2020-ICT-2016-2
# ES                                            H2020-FETHPC-2017
# CH                                           H2020-MSCA-IF-2016
# NL                                    H2020-SMEINST-1-2016-2017
# ES                                    H2020-SMEINST-2-2016-2017
# FI                                    H2020-SMEINST-2-2016-2017
# DE                                    H2020-SMEINST-2-2016-2017
# NL                                    H2020-SMEINST-2-2016-2017
# ES                                    H2020-SMEINST-2-2016-2017
# IT                                    H2020-SMEINST-2-2016-2017
# FR                                             H2020-ICT-2016-2
# IL                                    H2020-SMEINST-2-2016-2017
# ES                                             H2020-ICT-2016-2
# ES                                    H2020-SMEINST-2-2016-2017
# ES                                    H2020-SMEINST-2-2016-2017
# ES                                    H2020-SMEINST-2-2016-2017
# FI                                        H2020-INNOSUP-02-2016
# ES                                        H2020-INNOSUP-02-2016
# FI                                                 ERC-2016-COG
# ES                                      H2020-CS2-CFP03-2016-01
# CY                  H2020-WIDESPREAD-01-2016-2017-TeamingPhase2
# NL                                           H2020-MSCA-IF-2016
# FR                                      H2020-INFRAINNOV-2016-1
# ...                                                         ...
# IL                                                 ERC-2015-CoG
# IE                                                 ERC-2015-STG
# ES                                                 ERC-2016-ADG
# FR                               H2020-INFRAIA-2017-1-two-stage
# DE                                                 ERC-2016-ADG
# FR                                                 ERC-2015-STG
# BE                                           H2020-SC1-2016-RTD
# HU                                        H2020-MSCA-NIGHT-2014
# IE                                    H2020-SMEINST-2-2016-2017
# FR                                           H2020-MSCA-IF-2016
# NL                                             H2020-SFS-2014-2
# IE                                        H2020-MSCA-NIGHT-2014
# FI                                                 ERC-2015-STG
# NL                                                 ERC-2015-STG
# FI                                                 ERC-2015-STG
# DE                                                 ERC-2015-STG
# NL                                                 ERC-2015-STG
# ES                                              CIP-2016-2017-1
# ES                                          H2020-MSCA-ITN-2015
# DE                                                 ERC-2015-CoG
# FR                                                 ERC-2015-CoG
# ES                                                 ERC-2015-STG
# FR                                   H2020-LCE-2015-1-two-stage
# NO                                                 ERC-2015-AdG
# FR                                                 ERC-2017-COG
# FR                                           H2020-MSCA-IF-2017
# CH                                                 ERC-2015-CoG
# AT                                                 ERC-2015-AdG
# NL                                                 ERC-2015-CoG
# NL                                                 ERC-2015-PoC
#
#                     fundingScheme  \
# coordinatorCountry
# BE                          IA-LS
# IL                          SME-1
# FR                            CSA
# AT                            CSA
# BE                            CSA
# SE                          SME-1
# DK                          SME-1
# ES                             IA
# ES                            RIA
# CH                  MSCA-IF-EF-ST
# NL                          SME-1
# ES                          SME-2
# FI                          SME-2
# DE                          SME-2
# NL                          SME-2
# ES                          SME-2
# IT                          SME-2
# FR                             IA
# IL                          SME-2
# ES                             IA
# ES                          SME-2
# ES                          SME-2
# ES                          SME-2
# FI                            CSA
# ES                            CSA
# FI                        ERC-COG
# ES                         CS2-IA
# CY                        SGA-CSA
# NL                  MSCA-IF-EF-ST
# FR                            CSA
# ...                           ...
# IL                        ERC-COG
# IE                        ERC-STG
# ES                        ERC-ADG
# FR                            RIA
# DE                        ERC-ADG
# FR                        ERC-STG
# BE                            RIA
# HU                            CSA
# IE                          SME-2
# FR                     MSCA-IF-GF
# NL                            RIA
# IE                            CSA
# FI                        ERC-STG
# NL                        ERC-STG
# FI                        ERC-STG
# DE                        ERC-STG
# NL                        ERC-STG
# ES                             IA
# ES                   MSCA-ITN-ETN
# DE                        ERC-COG
# FR                        ERC-COG
# ES                        ERC-STG
# FR                            RIA
# NO                        ERC-ADG
# FR                        ERC-COG
# FR                  MSCA-IF-EF-ST
# CH                        ERC-COG
# AT                        ERC-ADG
# NL                        ERC-COG
# NL                        ERC-POC
#
#                                                           coordinator  \
# coordinatorCountry
# BE                                         INTRASOFT INTERNATIONAL SA
# IL                                                    SCOPIO LABS LTD
# FR                  ORGANISATION FOR ECONOMIC CO-OPERATION AND DEV...
# AT                                ZENTRUM FUR SOZIALE INNOVATION GMBH
# BE                    JRC -JOINT RESEARCH CENTRE- EUROPEAN COMMISSION
# SE                                                 BIBBINSTRUMENTS AB
# DK                                                  SIWI MASKINER APS
# ES                  FUNDACIO PRIVADA I2CAT, INTERNET I INNOVACIO D...
# ES                  BARCELONA SUPERCOMPUTING CENTER - CENTRO NACIO...
# CH                  FRIEDRICH MIESCHER INSTITUTE FOR BIOMEDICAL RE...
# NL                                           THE THINGS INDUSTRIES BV
# ES                                               NEXTCHANCE ASSETS SL
# FI                                                         OPTOMED OY
# DE                                              ESDA TECHNOLOGIE GMBH
# NL                                                       VANDERSAT BV
# ES                                            TERRAIN TECHNOLOGIES SL
# IT                                                        GLASSUP SRL
# FR                                             NOKIA BELL LABS FRANCE
# IL                                                     HOMEBIOGAS LTD
# ES                                                      ATOS SPAIN SA
# ES                                                  SOCIALDIABETES SL
# ES                                                        TECSELOR SL
# ES                                                        VADECITY SL
# FI                                                           EXTRX OY
# ES                                                MY THERAPY TOOLS SL
# FI                                                HELSINGIN YLIOPISTO
# ES                             CENTRO DE ENSAYOS Y ANALISIS CETEST SL
# CY                                               UNIVERSITY OF CYPRUS
# NL                                               UNIVERSITEIT UTRECHT
# FR                  COMMISSARIAT A L ENERGIE ATOMIQUE ET AUX ENERG...
# ...                                                               ...
# IL                                 THE HEBREW UNIVERSITY OF JERUSALEM
# IE                  THE PROVOST, FELLOWS, FOUNDATION SCHOLARS & TH...
# ES                                           UNIVERSIDAD POMPEU FABRA
# FR                      INSTITUT NATIONAL DE LA RECHERCHE AGRONOMIQUE
# DE                                              UNIVERSITAET ZU KOELN
# FR                  INSTITUT NATIONAL DE RECHERCHE ENINFORMATIQUE ...
# BE                                     KATHOLIEKE UNIVERSITEIT LEUVEN
# HU                  BAY ZOLTAN ALKALMAZOTT KUTATASI KOZHASZNU NONP...
# IE                                              SWIFTCOMPLY TOPCO LTD
# FR                                 UNIVERSITE DE BRETAGNE OCCIDENTALE
# NL                      RIJKSINSTITUUT VOOR VOLKSGEZONDHEID EN MILIEU
# IE                  THE PROVOST, FELLOWS, FOUNDATION SCHOLARS & TH...
# FI                                               ITA-SUOMEN YLIOPISTO
# NL                                  STICHTING KATHOLIEKE UNIVERSITEIT
# FI                                         AALTO KORKEAKOULUSAATIO SR
# DE                     RHEINISCHE FRIEDRICH-WILHELMS-UNIVERSITAT BONN
# NL                                                UNIVERSITEIT LEIDEN
# ES                  FUNDACION DE LA COMUNIDAD VALENCIANA PARA LA I...
# ES                  UNIVERSIDAD DEL PAIS VASCO/ EUSKAL HERRIKO UNI...
# DE                  GEORG-AUGUST-UNIVERSITAT GOTTINGENSTIFTUNG OFF...
# FR                  CENTRE NATIONAL DE LA RECHERCHE SCIENTIFIQUE CNRS
# ES                                             UNIVERSIDAD DE NAVARRA
# FR                       BUREAU DE RECHERCHES GEOLOGIQUES ET MINIERES
# NO                                             UNIVERSITETET I BERGEN
# FR                  CENTRE NATIONAL DE LA RECHERCHE SCIENTIFIQUE CNRS
# FR                  CENTRE NATIONAL DE LA RECHERCHE SCIENTIFIQUE CNRS
# CH                                                 UNIVERSITAT ZURICH
# AT                                     MEDIZINISCHE UNIVERSITAET WIEN
# NL                                  STICHTING KATHOLIEKE UNIVERSITEIT
# NL                                                UNIVERSITEIT LEIDEN
#
#                                                          participants  \
# coordinatorCountry
# BE                  [N.BAZIGOS ABEE, NEDERLANDSE ORGANISATIE VOOR ...
# IL                                                                NaN
# FR                                                                NaN
# AT                                                                NaN
# BE                                                                NaN
# SE                                                                NaN
# DK                                                                NaN
# ES                  [COMUNICARE DIGITALE - ASSOCIAZIONEDI PROMOZIO...
# ES                  [INSTITUT NATIONAL DE RECHERCHE ENINFORMATIQUE...
# CH                                                                NaN
# NL                                                                NaN
# ES                                                                NaN
# FI                                                                NaN
# DE                                                                NaN
# NL                                                                NaN
# ES                                                                NaN
# IT                                                                NaN
# FR                  [B-COM, ORANGE SA, INTERUNIVERSITAIR MICRO-ELE...
# IL                                                                NaN
# ES                  [NUROGAMES GMBH, CENTRE TECNOLOGIC DE TELECOMU...
# ES                                                                NaN
# ES                                                                NaN
# ES                                                                NaN
# FI                                                                NaN
# ES                                                                NaN
# FI                                                                NaN
# ES                           [ASOCIACION CENTRO TECNOLOGICO CEIT-IK4]
# CY                  [IMPERIAL COLLEGE OF SCIENCE TECHNOLOGY AND ME...
# NL                                                                NaN
# FR                  [THE HENRYK NIEWODNICZANSKI INSTITUTE OF NUCLE...
# ...                                                               ...
# IL                                                                NaN
# IE                                                                NaN
# ES                                                                NaN
# FR                  [VLAAMSE INSTELLING VOOR TECHNOLOGISCH ONDERZO...
# DE                      [THE REGENTS OF THE UNIVERSITY OF CALIFORNIA]
# FR                                           [INSTITUT MINES-TELECOM]
# BE                  [TTOPSTART BV, INC RESEARCH UK LTD, GRANZER HE...
# HU                  [TUDOMANYOS ISMERETTERJESZTO TARSULAT, REGIONA...
# IE                                                                NaN
# FR                                                                NaN
# NL                  [STATNI ZDRAVOTNI USTAV, UNIVERSITAT ROVIRA I ...
# IE                                                                NaN
# FI                                                                NaN
# NL                                                                NaN
# FI                                                                NaN
# DE                                                                NaN
# NL                  [MAX-PLANCK-GESELLSCHAFT ZUR FORDERUNG DER WIS...
# ES                  [IDEMIA IDENTITY & SECURITY FRANCE, INNOVASEC ...
# ES                  [STICHTING KATHOLIEKE UNIVERSITEIT, FRAUNHOFER...
# DE                                        [UNIVERSITY OF EAST ANGLIA]
# FR                                                                NaN
# ES                                                                NaN
# FR                  [FLODIM SARL, NHAZCA SRL, NEDERLANDSE ORGANISA...
# NO                                                                NaN
# FR                                                                NaN
# FR                                                                NaN
# CH                                                                NaN
# AT                                                                NaN
# NL                                                                NaN
# NL                                                                NaN
#
#                                                  participantCountries  \
# coordinatorCountry
# BE                               [EL, NL, ES, DE, IT, FR, AT, LU, LT]
# IL                                                                NaN
# FR                                                                NaN
# AT                                                                NaN
# BE                                                                NaN
# SE                                                                NaN
# DK                                                                NaN
# ES                                   [IT, ES, FR, BE, DE, UK, LU, PT]
# ES                                       [FR, SE, DE, BE, ES, PT, IT]
# CH                                                                NaN
# NL                                                                NaN
# ES                                                                NaN
# FI                                                                NaN
# DE                                                                NaN
# NL                                                                NaN
# ES                                                                NaN
# IT                                                                NaN
# FR                                   [FR, BE, ES, GI, DK, UK, IT, IL]
# IL                                                                NaN
# ES                               [DE, ES, BE, EL, IE, PT, CY, UK, FR]
# ES                                                                NaN
# ES                                                                NaN
# ES                                                                NaN
# FI                                                                NaN
# ES                                                                NaN
# FI                                                                NaN
# ES                                                               [ES]
# CY                                                               [UK]
# NL                                                                NaN
# FR                                       [PL, SE, UK, DE, CH, FR, IT]
# ...                                                               ...
# IL                                                                NaN
# IE                                                                NaN
# ES                                                                NaN
# FR                               [BE, DE, UK, FI, EL, FR, ES, IT, NL]
# DE                                                               [US]
# FR                                                               [FR]
# BE                                                   [NL, UK, DE, BE]
# HU                                                               [HU]
# IE                                                                NaN
# FR                                                                NaN
# NL                  [CZ, ES, DE, NO, UK, BE, SI, FR, IS, EL, CH, C...
# IE                                                                NaN
# FI                                                                NaN
# NL                                                                NaN
# FI                                                                NaN
# DE                                                                NaN
# NL                                                               [DE]
# ES                                   [FR, UK, AT, IT, SI, EL, ES, BE]
# ES                                               [NL, DE, SE, EL, UK]
# DE                                                               [UK]
# FR                                                                NaN
# ES                                                                NaN
# FR                               [FR, IT, NL, DE, NO, ES, UK, SK, CZ]
# NO                                                                NaN
# FR                                                                NaN
# FR                                                                NaN
# CH                                                                NaN
# AT                                                                NaN
# NL                                                                NaN
# NL                                                                NaN
#
#                    subjects  \
# coordinatorCountry
# BE                      NaN
# IL                      NaN
# FR                      NaN
# AT                      NaN
# BE                      NaN
# SE                      NaN
# DK                      NaN
# ES                      NaN
# ES                      NaN
# CH                      NaN
# NL                      NaN
# ES                      NaN
# FI                      NaN
# DE                      NaN
# NL                      NaN
# ES                      NaN
# IT                      NaN
# FR                      NaN
# IL                      NaN
# ES                      NaN
# ES                      NaN
# ES                      NaN
# ES                      NaN
# FI                      NaN
# ES                      NaN
# FI                      NaN
# ES                      NaN
# CY                      NaN
# NL                      NaN
# FR                      NaN
# ...                     ...
# IL                      NaN
# IE                      NaN
# ES                      NaN
# FR                      NaN
# DE                      NaN
# FR                      NaN
# BE                      NaN
# HU                      NaN
# IE                      NaN
# FR                      NaN
# NL                      NaN
# IE                      NaN
# FI                      NaN
# NL                      NaN
# FI                      NaN
# DE                      NaN
# NL                      NaN
# ES                      NaN
# ES                      NaN
# DE                      NaN
# FR                      NaN
# ES                      NaN
# FR                      NaN
# NO                      NaN
# FR                      NaN
# FR                      NaN
# CH                      NaN
# AT                      NaN
# NL                      NaN
# NL                      NaN
#
#                                                         organisations  \
# coordinatorCountry
# BE                  [INTRASOFT INTERNATIONAL SA, N.BAZIGOS ABEE, N...
# IL                                                  [SCOPIO LABS LTD]
# FR                  [ORGANISATION FOR ECONOMIC CO-OPERATION AND DE...
# AT                              [ZENTRUM FUR SOZIALE INNOVATION GMBH]
# BE                  [JRC -JOINT RESEARCH CENTRE- EUROPEAN COMMISSION]
# SE                                               [BIBBINSTRUMENTS AB]
# DK                                                [SIWI MASKINER APS]
# ES                  [FUNDACIO PRIVADA I2CAT, INTERNET I INNOVACIO ...
# ES                  [BARCELONA SUPERCOMPUTING CENTER - CENTRO NACI...
# CH                  [FRIEDRICH MIESCHER INSTITUTE FOR BIOMEDICAL R...
# NL                                         [THE THINGS INDUSTRIES BV]
# ES                                             [NEXTCHANCE ASSETS SL]
# FI                                                       [OPTOMED OY]
# DE                                            [ESDA TECHNOLOGIE GMBH]
# NL                                                     [VANDERSAT BV]
# ES                                          [TERRAIN TECHNOLOGIES SL]
# IT                                                      [GLASSUP SRL]
# FR                  [NOKIA BELL LABS FRANCE, B-COM, ORANGE SA, INT...
# IL                                                   [HOMEBIOGAS LTD]
# ES                  [ATOS SPAIN SA, NUROGAMES GMBH, CENTRE TECNOLO...
# ES                                                [SOCIALDIABETES SL]
# ES                                                      [TECSELOR SL]
# ES                                                      [VADECITY SL]
# FI                                                         [EXTRX OY]
# ES                                              [MY THERAPY TOOLS SL]
# FI                                              [HELSINGIN YLIOPISTO]
# ES                  [CENTRO DE ENSAYOS Y ANALISIS CETEST SL, ASOCI...
# CY                  [UNIVERSITY OF CYPRUS, IMPERIAL COLLEGE OF SCI...
# NL                                             [UNIVERSITEIT UTRECHT]
# FR                  [COMMISSARIAT A L ENERGIE ATOMIQUE ET AUX ENER...
# ...                                                               ...
# IL                               [THE HEBREW UNIVERSITY OF JERUSALEM]
# IE                  [THE PROVOST, FELLOWS, FOUNDATION SCHOLARS & T...
# ES                                         [UNIVERSIDAD POMPEU FABRA]
# FR                  [INSTITUT NATIONAL DE LA RECHERCHE AGRONOMIQUE...
# DE                  [UNIVERSITAET ZU KOELN, THE REGENTS OF THE UNI...
# FR                  [INSTITUT NATIONAL DE RECHERCHE ENINFORMATIQUE...
# BE                  [KATHOLIEKE UNIVERSITEIT LEUVEN, TTOPSTART BV,...
# HU                  [BAY ZOLTAN ALKALMAZOTT KUTATASI KOZHASZNU NON...
# IE                                            [SWIFTCOMPLY TOPCO LTD]
# FR                               [UNIVERSITE DE BRETAGNE OCCIDENTALE]
# NL                  [RIJKSINSTITUUT VOOR VOLKSGEZONDHEID EN MILIEU...
# IE                  [THE PROVOST, FELLOWS, FOUNDATION SCHOLARS & T...
# FI                                             [ITA-SUOMEN YLIOPISTO]
# NL                                [STICHTING KATHOLIEKE UNIVERSITEIT]
# FI                                       [AALTO KORKEAKOULUSAATIO SR]
# DE                   [RHEINISCHE FRIEDRICH-WILHELMS-UNIVERSITAT BONN]
# NL                  [UNIVERSITEIT LEIDEN, MAX-PLANCK-GESELLSCHAFT ...
# ES                  [FUNDACION DE LA COMUNIDAD VALENCIANA PARA LA ...
# ES                  [UNIVERSIDAD DEL PAIS VASCO/ EUSKAL HERRIKO UN...
# DE                  [GEORG-AUGUST-UNIVERSITAT GOTTINGENSTIFTUNG OF...
# FR                  [CENTRE NATIONAL DE LA RECHERCHE SCIENTIFIQUE ...
# ES                                           [UNIVERSIDAD DE NAVARRA]
# FR                  [BUREAU DE RECHERCHES GEOLOGIQUES ET MINIERES,...
# NO                                           [UNIVERSITETET I BERGEN]
# FR                  [CENTRE NATIONAL DE LA RECHERCHE SCIENTIFIQUE ...
# FR                  [CENTRE NATIONAL DE LA RECHERCHE SCIENTIFIQUE ...
# CH                                               [UNIVERSITAT ZURICH]
# AT                                   [MEDIZINISCHE UNIVERSITAET WIEN]
# NL                                [STICHTING KATHOLIEKE UNIVERSITEIT]
# NL                                              [UNIVERSITEIT LEIDEN]
#
#                                                             countries  \
# coordinatorCountry
# BE                           [BE, EL, NL, ES, DE, IT, FR, AT, LU, LT]
# IL                                                               [IL]
# FR                                                               [FR]
# AT                                                               [AT]
# BE                                                               [BE]
# SE                                                               [SE]
# DK                                                               [DK]
# ES                               [ES, IT, ES, FR, BE, DE, UK, LU, PT]
# ES                                   [ES, FR, SE, DE, BE, ES, PT, IT]
# CH                                                               [CH]
# NL                                                               [NL]
# ES                                                               [ES]
# FI                                                               [FI]
# DE                                                               [DE]
# NL                                                               [NL]
# ES                                                               [ES]
# IT                                                               [IT]
# FR                               [FR, FR, BE, ES, GI, DK, UK, IT, IL]
# IL                                                               [IL]
# ES                           [ES, DE, ES, BE, EL, IE, PT, CY, UK, FR]
# ES                                                               [ES]
# ES                                                               [ES]
# ES                                                               [ES]
# FI                                                               [FI]
# ES                                                               [ES]
# FI                                                               [FI]
# ES                                                           [ES, ES]
# CY                                                           [CY, UK]
# NL                                                               [NL]
# FR                                   [FR, PL, SE, UK, DE, CH, FR, IT]
# ...                                                               ...
# IL                                                               [IL]
# IE                                                               [IE]
# ES                                                               [ES]
# FR                           [FR, BE, DE, UK, FI, EL, FR, ES, IT, NL]
# DE                                                           [DE, US]
# FR                                                           [FR, FR]
# BE                                               [BE, NL, UK, DE, BE]
# HU                                                           [HU, HU]
# IE                                                               [IE]
# FR                                                               [FR]
# NL                  [NL, CZ, ES, DE, NO, UK, BE, SI, FR, IS, EL, C...
# IE                                                               [IE]
# FI                                                               [FI]
# NL                                                               [NL]
# FI                                                               [FI]
# DE                                                               [DE]
# NL                                                           [NL, DE]
# ES                               [ES, FR, UK, AT, IT, SI, EL, ES, BE]
# ES                                           [ES, NL, DE, SE, EL, UK]
# DE                                                           [DE, UK]
# FR                                                               [FR]
# ES                                                               [ES]
# FR                           [FR, FR, IT, NL, DE, NO, ES, UK, SK, CZ]
# NO                                                               [NO]
# FR                                                               [FR]
# FR                                                               [FR]
# CH                                                               [CH]
# AT                                                               [AT]
# NL                                                               [NL]
# NL                                                               [NL]
#
#                    startYear  endYear
# coordinatorCountry
# BE                    2018.0   2022.0
# IL                    2018.0   2018.0
# FR                    2018.0   2021.0
# AT                    2018.0   2019.0
# BE                    2018.0   2020.0
# SE                    2018.0   2018.0
# DK                    2018.0   2018.0
# ES                    2017.0   2019.0
# ES                    2018.0   2021.0
# CH                    2018.0   2019.0
# NL                    2018.0   2018.0
# ES                    2017.0   2019.0
# FI                    2017.0   2019.0
# DE                    2017.0   2019.0
# NL                    2017.0   2019.0
# ES                    2017.0   2019.0
# IT                    2017.0   2019.0
# FR                    2017.0   2019.0
# IL                    2017.0   2019.0
# ES                    2017.0   2019.0
# ES                    2017.0   2019.0
# ES                    2017.0   2019.0
# ES                    2017.0   2019.0
# FI                    2017.0   2018.0
# ES                    2018.0   2019.0
# FI                    2017.0   2022.0
# ES                    2017.0   2020.0
# CY                    2017.0   2024.0
# NL                    2017.0   2019.0
# FR                    2017.0   2019.0
# ...                      ...      ...
# IL                    2016.0   2021.0
# IE                    2016.0   2021.0
# ES                    2018.0   2022.0
# FR                    2017.0   2021.0
# DE                    2018.0   2023.0
# FR                    2016.0   2021.0
# BE                    2017.0   2022.0
# HU                    2014.0   2015.0
# IE                    2017.0   2019.0
# FR                    2018.0   2021.0
# NL                    2015.0   2019.0
# IE                    2014.0   2015.0
# FI                    2017.0   2021.0
# NL                    2016.0   2021.0
# FI                    2016.0   2021.0
# DE                    2016.0   2021.0
# NL                    2017.0   2022.0
# ES                    2017.0   2020.0
# ES                    2016.0   2020.0
# DE                    2016.0   2021.0
# FR                    2016.0   2021.0
# ES                    2016.0   2021.0
# FR                    2016.0   2020.0
# NO                    2016.0   2021.0
# FR                    2018.0   2023.0
# FR                    2018.0   2020.0
# CH                    2016.0   2021.0
# AT                    2016.0   2021.0
# NL                    2016.0   2021.0
# NL                    2016.0   2018.0
#
# [16829 rows x 24 columns]

# %% [markdown]
# **Handling Missing Data**

# %%
cordis_projects_df.isnull()

# %%
cordis_projects_df[cordis_projects_df['participants'].isnull() == True]

# %%
# another way to drop columns where all elements are nan
#use toy here
df.dropna(axis = 1, how='any')

# %%
# another way to drop rows where all elements are nan; here axis =0 by default
df.dropna(how='any')

# %% [markdown]
# **_Task_**
# <br/>There are other `how` parameter options. See what happens when `how` equals `all`

# %%
# write code here

# %% [markdown]
# **Duplicates & Drop Duplicates**

# %%
df.duplicates()

# %%
df.drop_duplicates()

#can drop duplicates based on one column 
df.drop_duplicates(subset="col", inplace=True)

# %% [markdown]
# **Replace**

# %%
df_1.replace(np.nan, 0.0)#, inplace=True) #inplace makes permanent changes without having to replace the df vare

# %% [markdown]
# **Rename & Resets**

# %%
# renaming columns
# reset index
#set indexb

# %% [markdown]
# In cases of dropping rows, this will not automatically reset the indexes. This is where `reset_index` comes in handy.

# %%
toy_1.drop(1)
# Out:
#   col1 col2  col3  col4
# 0    a    d   1.0     4
# 2  NaN    f   3.0     6
# 3    c    g   NaN     7

# %%
toy_1.drop(1).reset_index()
# Out:
#    index col1 col2  col3  col4
# 0      0    a    d   1.0     4
# 1      2  NaN    f   3.0     6
# 2      3    c    g   NaN     7

# %%
#drop parameter deletes the original indexes
toy_1.drop(1).reset_index(drop=True)
# Out:
#   col1 col2  col3  col4
# 0    a    d   1.0     4
# 1  NaN    f   3.0     6
# 2    c    g   NaN     7

# %% [markdown]
# **Sort**

# %%
toy_1.sort_values('col4')
# Out:
#   col1 col2  col3  col4
# 0    a    d   1.0     4
# 3    c    g   NaN     5
# 2  NaN    f   3.0     6
# 1    b    e   2.0     7

# %% [markdown]
# ## Tranformation

# %%
# add new columns
#group data & apply a function & mergeb
#refer back to adat types and how we change datatype of column

# %% [markdown]
# **Transpose**
# <br/> To invert the the dimensions of the dataframe.

# %%
toy_1.T
# Out:
#       0  1    2    3
# col1  a  b  NaN    c
# col2  d  e    f    g
# col3  1  2    3  NaN
# col4  4  5    6    7

# %%
#transpose data

df.T

# %% [markdown]
# **Mapping**

# %%
# returning back to this df
uk_df = cordis_projects_df.loc[cordis_projects_df['coordinatorCountry'] == 'UK']

# %%
replace_dict = {'UK' : 'England, Scotland, Wales and NI'}

# %%
uk_df['coordinatorCountry'].map(replace_dict).head()

# %% [markdown]
# ### GroupBy
#
# The `groupby` function allows for one to perform calculations and analysis on split or "grouped" data.

# %%
# returns a generator
cordis_projects_df.groupby(by=['status'])

# %% [markdown]
# Here, we can investigate statistical results of each numerical column based on the groups defined by applying the methods form earlier.

# %%
cordis_projects_df.groupby(by=['status']).mean()
# Out:
#                       rcn             id     totalCost  ecMaxContribution  \
# status
# CLOSED      200358.081405  692498.117318  4.378749e+05       3.389019e+05
# SIGNED      206384.141832  726695.553194  2.313069e+06       1.877964e+06
# TERMINATED  201289.196388  693269.027088  5.741743e+05       4.507264e+05
#
#             subjects    startYear      endYear
# status
# CLOSED           NaN  2015.541101  2016.671189
# SIGNED           NaN  2016.633702  2019.344723
# TERMINATED       NaN  2016.054795  2018.169492

# %%
cordis_projects_df.groupby(by=['status']).sum()
# Out:
#                    rcn           id     totalCost  ecMaxContribution  \
# status
# CLOSED       251048676    867700141  5.486573e+08       4.246441e+08
# SIGNED      3883736781  13674956920  4.351808e+10       3.533953e+10
# TERMINATED    89171114    307118179  2.543592e+08       1.996718e+08
#
#             subjects   startYear     endYear
# status
# CLOSED           0.0   2525473.0   2526889.0
# SIGNED           0.0  37949013.0  38000029.0
# TERMINATED       0.0    883032.0    833504.0

# %%
# can groupby on different levels and cal on diff levels

# %%
#careful cos some columns may have integers but are IDs 
#so up to you to make decision what to do with it

# %% [markdown]
# # Combining Data
# <br/>Combining data is important in cases where one may have multiple datasets. This is useful when enriching data.

# %% [markdown]
# ## Merge
#
# In Pandas, there are various ways to merge: `left`, `right`, `inner`, `outer`. Here, we have to specify

# %%
# merge - `left` specifies the first is the main dataframe and the other is mergeing with it 
# note, the columns must be the same in order for a smooth merge
#note the col chosen of the chosen df of is constant and everything is depent on that (Whether it includes the lement in it's respective row)
pd.merge(
    toy_1,
    toy_2,
    how='left', 
    on= 'col2'
)

# %% [markdown]
# **_Task_**
# <br/>Now see what happens when the `how` parameter equals `right`, `inner` and `outer`.

# %%
# write code here

# %% [markdown]
# ## Concatenate
# Concatenating is another why of combining datasets which simply stacks two or more dataframes besides (across rows) or on-top of each other(across columns).

# %%
# default axis= 0
pd.concat([df_1,df_2])

# %%
pd.concat([df_1,df_2], axis=1)# where it's concatenated in ord on

# %% [markdown]
# # Working with...
#
# Here, we will look at different non-numeric data type and how we can work with them in pandas.

# %% [markdown]
# ## DateTime
# <br />
# Luckily, the datetime fields in the Cordis dataset include datetime objects. In a lot of cases, datetime information are stored as strings. Thankfully, pandas can deal with this. These strings are transformed to datetime objects.

# %%
toy_date_series = pd.Series(
        ['19-08-01', '16-05-18', '25-04-17']
)

# %%
toy_date_series_transformed = pd.to_datetime(toy_date_series)

# %%
# for example, the first row 
print(toy_date_series_transformed[0].year)
print(toy_date_series_transformed[0].month)
print(toy_date_series_transformed[0].day)
# Out:
# 2001
# 8
# 19

# %% [markdown]
# ## Strings
# <br/>When working with data, you will most likely come across strings. Pandas offers the `str()` function to deal with such. This function discards of `NaN` values.

# %%
# apply lower case to all tokens
cordis_projects_df['title'].str.lower()
# Out:
# 0        digital dynamic knowledge platform for welding...
# 1        a multi-sided business platform for plug and p...
# 2        high-resolution, all-digital microscope that a...
# 3        microdata analysis for policies for productivi...
# 4        conference on the âimpact of social sciences...
# 5         global industrial research & innovation analyses
# 6        endodrillâ® model x - a new endoscopic biopsy ...
# 7        automatic hitching for total safety of farmers...
# 8                                                   5gcity
# 9        european joint effort toward a highly producti...
# 10       functional exploration of the contributions of...
# 11       fast iot market take-up through the things net...
# 12       the most cost-efficient video ad creation plat...
# 13       affordable, accessible and automatic screening...
# 14       high-capacity and high-performance thermal ene...
# 15       securing water for food and safety with the wo...
# 16       siade saas: spatial decision support system fo...
# 17       delivering contextual information in a hands-f...
# 18                   next generation platform as a service
# 19        turning food industry's organic wastw into value
# 20       5g development and validation platform for glo...
# 21                           hack your diabetes experience
# 22       a rapid, non-invasive, cost-effective, analyti...
# 23       ultraclean thermoforming equipment for food pa...
# 24       ultra-robust, flexible organic sensors for app...
# 25                        safe parking system for bicycles
# 26       novel application targets and products derived...
# 27       sme innovation associate: matching mytherapyto...
# 28       molecular foundation of structural and dynamic...
# 29       resistance evolution in response to spatially ...
#                                ...
# 20484                   amber - enhanced mobile biometrics
# 20485    looking over the horizon - horizontal prioriti...
# 20486    a technology marketplace for hospitality compl...
# 20487    unravelling the effect of origin number on the...
# 20488    mechanisms of coupling of ocean dynamics and i...
# 20489                                              euromix
# 20490    discover research dublin - european researcher...
# 20491    individual vascular signature: a new machine l...
# 20492    operation condor: accountability for transnati...
# 20493    slowing down climate change: combining climate...
# 20494    participatory urban governance between democra...
# 20495    hrmeg: high-resolution magnetoencephalography:...
# 20496    analysis and representation of complex activit...
# 20497    plant foods in human evolution: factors affect...
# 20498    scalable multidimensional situation awareness ...
# 20499           enriched communication across the lifespan
# 20500    oxygen flux measurements as a new tracer for t...
# 20501                       quantum communications for all
# 20502    invasive cognitive brain computer interfaces t...
# 20503    integrated next-generation flow cytometry and ...
# 20504               enabling onshore co2 storage in europe
# 20505    advanced spectroscopy and spectrometry for ima...
# 20506    perception of voices that do not exist: tracki...
# 20507    vinyl and heteroaryl boronic acids as non-stab...
# 20508    the function of membrane tethering in plant in...
# 20509    imaging and analyzing dynamics of reward-relat...
# 20510    bacterial cooperation at the individual cell l...
# 20511    cellular diversity and stress-induced cell-sta...
# 20512    middlebrow enlightenment: disseminating ideas,...
# 20513    development of a potent dual gcs/gba2 inhibito...
# Name: title, Length: 20514, dtype: object

# %%
# apply upper case to all tokens
cordis_projects_df['title'].str.upper()
# Out:
# 0        DIGITAL DYNAMIC KNOWLEDGE PLATFORM FOR WELDING...
# 1        A MULTI-SIDED BUSINESS PLATFORM FOR PLUG AND P...
# 2        HIGH-RESOLUTION, ALL-DIGITAL MICROSCOPE THAT A...
# 3        MICRODATA ANALYSIS FOR POLICIES FOR PRODUCTIVI...
# 4        CONFERENCE ON THE ÂIMPACT OF SOCIAL SCIENCES...
# 5         GLOBAL INDUSTRIAL RESEARCH & INNOVATION ANALYSES
# 6        ENDODRILLÂ® MODEL X - A NEW ENDOSCOPIC BIOPSY ...
# 7        AUTOMATIC HITCHING FOR TOTAL SAFETY OF FARMERS...
# 8                                                   5GCITY
# 9        EUROPEAN JOINT EFFORT TOWARD A HIGHLY PRODUCTI...
# 10       FUNCTIONAL EXPLORATION OF THE CONTRIBUTIONS OF...
# 11       FAST IOT MARKET TAKE-UP THROUGH THE THINGS NET...
# 12       THE MOST COST-EFFICIENT VIDEO AD CREATION PLAT...
# 13       AFFORDABLE, ACCESSIBLE AND AUTOMATIC SCREENING...
# 14       HIGH-CAPACITY AND HIGH-PERFORMANCE THERMAL ENE...
# 15       SECURING WATER FOR FOOD AND SAFETY WITH THE WO...
# 16       SIADE SAAS: SPATIAL DECISION SUPPORT SYSTEM FO...
# 17       DELIVERING CONTEXTUAL INFORMATION IN A HANDS-F...
# 18                   NEXT GENERATION PLATFORM AS A SERVICE
# 19        TURNING FOOD INDUSTRY'S ORGANIC WASTW INTO VALUE
# 20       5G DEVELOPMENT AND VALIDATION PLATFORM FOR GLO...
# 21                           HACK YOUR DIABETES EXPERIENCE
# 22       A RAPID, NON-INVASIVE, COST-EFFECTIVE, ANALYTI...
# 23       ULTRACLEAN THERMOFORMING EQUIPMENT FOR FOOD PA...
# 24       ULTRA-ROBUST, FLEXIBLE ORGANIC SENSORS FOR APP...
# 25                        SAFE PARKING SYSTEM FOR BICYCLES
# 26       NOVEL APPLICATION TARGETS AND PRODUCTS DERIVED...
# 27       SME INNOVATION ASSOCIATE: MATCHING MYTHERAPYTO...
# 28       MOLECULAR FOUNDATION OF STRUCTURAL AND DYNAMIC...
# 29       RESISTANCE EVOLUTION IN RESPONSE TO SPATIALLY ...
#                                ...
# 20484                   AMBER - ENHANCED MOBILE BIOMETRICS
# 20485    LOOKING OVER THE HORIZON - HORIZONTAL PRIORITI...
# 20486    A TECHNOLOGY MARKETPLACE FOR HOSPITALITY COMPL...
# 20487    UNRAVELLING THE EFFECT OF ORIGIN NUMBER ON THE...
# 20488    MECHANISMS OF COUPLING OF OCEAN DYNAMICS AND I...
# 20489                                              EUROMIX
# 20490    DISCOVER RESEARCH DUBLIN - EUROPEAN RESEARCHER...
# 20491    INDIVIDUAL VASCULAR SIGNATURE: A NEW MACHINE L...
# 20492    OPERATION CONDOR: ACCOUNTABILITY FOR TRANSNATI...
# 20493    SLOWING DOWN CLIMATE CHANGE: COMBINING CLIMATE...
# 20494    PARTICIPATORY URBAN GOVERNANCE BETWEEN DEMOCRA...
# 20495    HRMEG: HIGH-RESOLUTION MAGNETOENCEPHALOGRAPHY:...
# 20496    ANALYSIS AND REPRESENTATION OF COMPLEX ACTIVIT...
# 20497    PLANT FOODS IN HUMAN EVOLUTION: FACTORS AFFECT...
# 20498    SCALABLE MULTIDIMENSIONAL SITUATION AWARENESS ...
# 20499           ENRICHED COMMUNICATION ACROSS THE LIFESPAN
# 20500    OXYGEN FLUX MEASUREMENTS AS A NEW TRACER FOR T...
# 20501                       QUANTUM COMMUNICATIONS FOR ALL
# 20502    INVASIVE COGNITIVE BRAIN COMPUTER INTERFACES T...
# 20503    INTEGRATED NEXT-GENERATION FLOW CYTOMETRY AND ...
# 20504               ENABLING ONSHORE CO2 STORAGE IN EUROPE
# 20505    ADVANCED SPECTROSCOPY AND SPECTROMETRY FOR IMA...
# 20506    PERCEPTION OF VOICES THAT DO NOT EXIST: TRACKI...
# 20507    VINYL AND HETEROARYL BORONIC ACIDS AS NON-STAB...
# 20508    THE FUNCTION OF MEMBRANE TETHERING IN PLANT IN...
# 20509    IMAGING AND ANALYZING DYNAMICS OF REWARD-RELAT...
# 20510    BACTERIAL COOPERATION AT THE INDIVIDUAL CELL L...
# 20511    CELLULAR DIVERSITY AND STRESS-INDUCED CELL-STA...
# 20512    MIDDLEBROW ENLIGHTENMENT: DISSEMINATING IDEAS,...
# 20513    DEVELOPMENT OF A POTENT DUAL GCS/GBA2 INHIBITO...
# Name: title, Length: 20514, dtype: object

# %%
cordis_projects_df['title'].str.len().head()

# %% [markdown]
# **_Task_**
# <br/>See what happens when using the `split()` function

# %%
# write code here
# Out:
# 0        [Digital, Dynamic, Knowledge, Platform, for, W...
# 1        [A, Multi-Sided, Business, Platform, for, Plug...
# 2        [High-resolution,, all-digital, microscope, th...
# 3        [Microdata, analysis, for, Policies, for, Prod...
# 4        [Conference, on, the, âImpact, of, Social, S...
# 5        [Global, Industrial, Research, &, Innovation, ...
# 6        [EndodrillÂ®, Model, X, -, a, new, endoscopic,...
# 7        [Automatic, Hitching, for, total, Safety, of, ...
# 8                                                 [5GCITY]
# 9        [European, joint, Effort, toward, a, Highly, P...
# 10       [Functional, exploration, of, the, contributio...
# 11       [Fast, IoT, market, take-up, through, The, Thi...
# 12       [The, most, cost-efficient, video, ad, creatio...
# 13       [Affordable,, accessible, and, automatic, scre...
# 14       [High-capacity, and, high-performance, Thermal...
# 15       [Securing, water, for, food, and, safety, with...
# 16       [SIADE, SaaS:, Spatial, Decision, Support, Sys...
# 17       [Delivering, contextual, information, in, a, h...
# 18            [Next, Generation, Platform, as, a, Service]
# 19       [Turning, food, industry's, organic, wastw, in...
# 20       [5G, Development, and, validation, platform, f...
# 21                      [Hack, your, Diabetes, Experience]
# 22       [A, rapid,, non-invasive,, cost-effective,, an...
# 23       [UltraCLEAN, thermoforming, equipment, for, fo...
# 24       [Ultra-robust,, flexible, organic, sensors, fo...
# 25                  [Safe, parking, system, for, bicycles]
# 26       [Novel, application, targets, and, products, d...
# 27       [SME, Innovation, Associate:, matching, MyTher...
# 28       [Molecular, Foundation, of, Structural, and, D...
# 29       [Resistance, evolution, in, response, to, spat...
#                                ...
# 20484             [AMBER, -, enhAnced, Mobile, BiomEtRics]
# 20485    [Looking, over, the, Horizon, -, horizontal, p...
# 20486    [A, technology, marketplace, for, hospitality,...
# 20487    [Unravelling, the, effect, of, origin, number,...
# 20488    [MEchanisms, of, Coupling, of, Ocean, Dynamics...
# 20489                                            [EuroMix]
# 20490    [Discover, Research, Dublin, -, European, Rese...
# 20491    [INdividual, Vascular, SignaTure:, A, new, mac...
# 20492    [Operation, Condor:, Accountability, for, Tran...
# 20493    [Slowing, Down, Climate, Change:, Combining, C...
# 20494    [Participatory, Urban, Governance, between, De...
# 20495    [HRMEG:, High-resolution, magnetoencephalograp...
# 20496    [Analysis, and, Representation, of, Complex, A...
# 20497    [Plant, foods, in, human, evolution:, Factors,...
# 20498    [Scalable, multidimensionAl, sitUation, awaRen...
# 20499     [Enriched, communication, across, the, lifespan]
# 20500    [Oxygen, flux, measurements, as, a, new, trace...
# 20501                  [Quantum, Communications, for, ALL]
# 20502    [Invasive, cognitive, brain, computer, interfa...
# 20503    [Integrated, next-generation, flow, cytometry,...
# 20504        [ENabling, Onshore, CO2, Storage, in, Europe]
# 20505    [Advanced, Spectroscopy, and, Spectrometry, fo...
# 20506    [Perception, of, voices, that, do, not, exist:...
# 20507    [VINYL, AND, HETEROARYL, BORONIC, ACIDS, AS, N...
# 20508    [The, function, of, membrane, tethering, in, p...
# 20509    [Imaging, and, analyzing, dynamics, of, reward...
# 20510    [Bacterial, cooperation, at, the, individual, ...
# 20511    [Cellular, diversity, and, stress-induced, cel...
# 20512    [Middlebrow, Enlightenment:, Disseminating, Id...
# 20513    [Development, of, a, potent, dual, GCS/GBA2, i...
# Name: title, Length: 20514, dtype: object

# %% [markdown]
# # Plotting

# %% [markdown]
# ## Pandas Plotting
# https://pandas.pydata.org/pandas-docs/stable/user_guide/visualization.html

# %%
#histogram plot - all pandas plota are matplotlib figs but are specifically pandas functions
# cordis_projects_df['startYear'].plot(kind='bar')
# plt.show()

# %%
# cordis_projects_df.columns

# %%
# cordis_projects_df.plot(x='ecMaxContribution',y='totalCost')

# %%
# cordis_projects_df['totalCost'].plot(kind='bar')

# %%
cordis_projects_df.plot(x ='startYear', y = 'totalCost', kind='scatter')

# %%
#using the groupby df
cordis_projects_df.groupby(by=['status']).mean().plot(kind='bar')
plt.grid(alpha=0.2)

# %%
cordis_projects_df.groupby(by=['status']).mean().unstack(0).plot(kind='bar')

# %%
# can stack - quite hard to see the size of each column result
cordis_projects_df.groupby(by=['status']).mean().plot(kind='bar', stacked=True)
plt.grid(alpha=0.2)

# %% [markdown]
# ## Plotting using MatplotLib
#
# https://matplotlib.org/3.1.1/contents.html

# %%
#to show they can be thrown into 
# one example with matplotlib
# counts = cordis_projects_df['startYear'].value_counts()
plt.scatter(cordis_projects_df['startYear'], cordis_projects_df['totalCost'])

# %%
cordis_projects_df.groupby(by=['status']).mean()
# Out:
#                       rcn             id     totalCost  ecMaxContribution  \
# status
# CLOSED      200358.081405  692498.117318  4.378749e+05       3.389019e+05
# SIGNED      206384.141832  726695.553194  2.313069e+06       1.877964e+06
# TERMINATED  201289.196388  693269.027088  5.741743e+05       4.507264e+05
#
#             subjects    startYear      endYear
# status
# CLOSED           NaN  2015.541101  2016.671189
# SIGNED           NaN  2016.633702  2019.344723
# TERMINATED       NaN  2016.054795  2018.169492

# %%
# cordis_projects_df.groupby(by=['status']).mean().plot(kind='bar', stacked=True)
# plt.grid(alpha=0.2)
plt.bar(cordis_projects_df.groupby(by=['status']).mean()['ecMaxContribution'].index, cordis_projects_df.groupby(by=['status']).mean()['ecMaxContribution'].values)
# Out:
# <BarContainer object of 3 artists>

# %% [markdown]
# # Export & Save

# %%
df.to_csv('directory/to/file_name.csv')

# %%
df.to_csv('/directory/to/file_name.csv', header=False, index=False) #doesnt save column names or indexes in the output

# %% [markdown]
# Other ways to save dataframe

# %% [markdown]
# # Available Datasets

# %% [markdown]
# How to read these

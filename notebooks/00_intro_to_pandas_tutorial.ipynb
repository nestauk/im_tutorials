# %% [markdown]
# # Simple Intro to Pandas
#
# This tutrorial looks at the use of the popular python library Pandas. This is widely used to work with big datasets in ways which one can explore, clean, transformm and wrangle.
#
# **Tutorial Structure**
# - [Preamble](#Preamble)
# - [Import Data](#Import-Data)
#  - [Creating DataFrames](#Creating-DataFrames)
#  - [Read Files](#Read-Files)

# %% [markdown]
# # Preamble

# %%
# %load_ext autoreload
# %autoreload 2
# install im_tutorial package
# !pip install git+https://github.com/nestauk/im_tutorials.git
# Out:
# Collecting git+https://github.com/nestauk/im_tutorials.git
#   Cloning https://github.com/nestauk/im_tutorials.git to /tmp/pip-req-build-ifijq3jx
#   Running command git clone -q https://github.com/nestauk/im_tutorials.git /tmp/pip-req-build-ifijq3jx
# Requirement already satisfied (use --upgrade to upgrade): im-tutorials==0.1.0 from git+https://github.com/nestauk/im_tutorials.git in /home/ao95/miniconda3/envs/pyenv_nesta/lib/python3.6/site-packages
# Building wheels for collected packages: im-tutorials
#   Building wheel for im-tutorials (setup.py) ... done
#   Created wheel for im-tutorials: filename=im_tutorials-0.1.0-cp36-none-any.whl size=12596 sha256=92a0dae1b151a8fce917671609755fe96e3efad3feeda198d43e6edde962bd3c
#   Stored in directory: /tmp/pip-ephem-wheel-cache-4hg8539_/wheels/47/a3/cb/bdc5f9ba49bcfd2c6864b166a1566eb2f104113bf0c3500330
# Successfully built im-tutorials

# %%
# numpy for mathematical functions
import numpy as np
# pandas for handling tabular data
import pandas as pd
# explained later
from im_tutorials.data import cordis
import matplotlib.pyplot as plt

# %% [markdown]
# # Import Data

# %% [markdown]
# ## Creating DataFrames
#
# There are cases where you may hardcode for hacking-uses. This is one way to create a dataframe from scratch.

# %%
# useful for hacking
df_1 = pd.DataFrame(
    {'col1' : ['a', 'b', None,'c'],
    'col2' : ['d', 'e', 'f','g'],
    'col3' : [1, 2, 3, None],
    'col4' : [4, 5, 6, 7]}
)

# %%
df_1

# %% [markdown]
# ## Read Files

# %%
#i if working from a local .csv file
df = pd.read_csv('file.csv')

# %%
# maybe use cordis
cordis_projects_df = cordis.h2020_projects()
# Out:
# /home/ao95/miniconda3/envs/pyenv_nesta/lib/python3.6/site-packages/smart_open/smart_open_lib.py:398: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL

# %% [markdown]
# # A Look at the Data
# <br/>
# It is almost protocol to look at what's inside your dataset before you start to answer questions. Pandas allows us to easily explore and draw up basic analysis using some of the libraries methods and functions.

# %% [markdown]
# Sometimes, we want a peek at what is going inside. The functions `.head()` and `.tail()` displays the top n rows or last n rows, respectively. Here, `n = 5` rows by default. You can adjust the number of rows by simply changing the number.

# %%
cordis_projects_df.head(n=3)
# Out:
#       rcn      id     acronym  status  \
# 0  218249  822106  WeldGalaxy  SIGNED
# 1  218272  822064   MARKET4.0  SIGNED
# 2  216937  816551      SCOPIO  SIGNED
#
#                                      programme                 topics  \
# 0         [H2020-EU.2.1.3., H2020-EU.2.1.5.1.]        DT-NMBP-20-2018
# 1         [H2020-EU.2.1.3., H2020-EU.2.1.5.1.]        DT-NMBP-20-2018
# 2  [H2020-EU.3., H2020-EU.2.3., H2020-EU.2.1.]  EIC-SMEInst-2018-2020
#
#   frameworkProgramme                                              title  \
# 0              H2020  Digital Dynamic Knowledge Platform for Welding...
# 1              H2020  A Multi-Sided Business Platform for Plug and P...
# 2              H2020  High-resolution, all-digital microscope that a...
#
#    startDate    endDate   ...   fundingScheme                 coordinator  \
# 0 2018-10-01 2022-03-31   ...           IA-LS                 TWI LIMITED
# 1 2018-11-01 2022-04-30   ...           IA-LS  INTRASOFT INTERNATIONAL SA
# 2 2018-05-01 2018-08-31   ...           SME-1             SCOPIO LABS LTD
#
#    coordinatorCountry                                       participants  \
# 0                  UK  [LULEA TEKNISKA UNIVERSITET, ROMSOFT SRL, TECH...
# 1                  BE  [N.BAZIGOS ABEE, NEDERLANDSE ORGANISATIE VOOR ...
# 2                  IL                                                NaN
#
#                    participantCountries subjects  \
# 0      [SE, RO, UK, NO, PL, FR, IL, ES]      NaN
# 1  [EL, NL, ES, DE, IT, FR, AT, LU, LT]      NaN
# 2                                   NaN      NaN
#
#                                        organisations  \
# 0  [TWI LIMITED, LULEA TEKNISKA UNIVERSITET, ROMS...
# 1  [INTRASOFT INTERNATIONAL SA, N.BAZIGOS ABEE, N...
# 2                                  [SCOPIO LABS LTD]
#
#                                   countries startYear endYear
# 0      [UK, SE, RO, UK, NO, PL, FR, IL, ES]    2018.0  2022.0
# 1  [BE, EL, NL, ES, DE, IT, FR, AT, LU, LT]    2018.0  2022.0
# 2                                      [IL]    2018.0  2018.0
#
# [3 rows x 25 columns]

# %%
cordis_projects_df.tail(n=3)

# %% [markdown]
# Dtataframes consist of indices

# %%
cordis_projects_df.index

# %%
cordis_projects_df.columns

# %% [markdown]
# There are cases where you may want to apply some calculations across rows or columns. This can be appoached by using the `axis` of the dataframe. This can be accessed using the `axis` parameter found in many methods (many are `axis = 0` but default).
# - Axis 0- apply on all rows across each column
# - Axis 1- apply on all columns across each row
#
# <img src="../reports/figures/axis.png">

# %%
cordis_projects_df.dtypes
#panadas way of saying there's non-numerical data in the column

# %%
cordis_projects_df.index

# %%
cordis_projects_df.columns
# Out:
# Index(['rcn', 'id', 'acronym', 'status', 'programme', 'topics',
#        'frameworkProgramme', 'title', 'startDate', 'endDate', 'projectUrl',
#        'objective', 'totalCost', 'ecMaxContribution', 'call', 'fundingScheme',
#        'coordinator', 'coordinatorCountry', 'participants',
#        'participantCountries', 'subjects', 'organisations', 'countries',
#        'startYear', 'endYear'],
#       dtype='object')

# %%
#can look at columns separtely 
cordis_projects_df['subjects']

# %%
#list of columns
cordis_projects_df[['status', 'subjects']]

# %%
cordis_projects_df['topics'].value_counts()

# %% [markdown]
# ## Maths & Summaries
# <br/>
# Many

# %%
df.sum()

# %%
# we can also use axis here 
df.sum(axis=1)

# %%
# count of number of elements present in column
df.count()

# %%
# or if you want the result of one column (can do this for any method)
df['col3'].count()

# %%
# only on numerical columns
df.describe()

# %%
#or can separately get this results
df.mean()

# %% [markdown]
# Now try other methods such as `.min()`, .max(), .median(), .var() and .std().

# %%
# write code here

# %%
#can add across columns

df['col3'] + df['col4']

# %% [markdown]
# Now try add two columns that have different datatypes and see what happens

# %%
# write code here

# %% [markdown]
# # Filtering & Subsets

# %%
# getting the subset of where the condition is true 
cordis_projects_df[cordis_projects_df['coordinatorCountry'] == 'UK'].head()

# %%
#instead of this, can use .loc 

cordis_projects_df.loc[cordis_projects_df['coordinatorCountry'] == 'UK']
# Out:
#           rcn      id               acronym      status  \
# 0      218249  822106            WeldGalaxy      SIGNED
# 22     210626  755667            BreathSpec      SIGNED
# 24     208925  747461   Robust OTFT sensors      SIGNED
# 28     208684  750294              NAPANODE  TERMINATED
# 30     208574  745808               BCSC-ST  TERMINATED
# 36     208532  739795                ASSIGN      SIGNED
# 39     207376  714427            INNOVATION      SIGNED
# 50     206181  732194                 QROWD      SIGNED
# 59     206125  705600   MultimodalCellTrack      SIGNED
# 66     206460  704382       BeeSymOverSpace      SIGNED
# 73     206229  730863               INNOWAG      SIGNED
# 78     204907  701737             SNAPTRACE      SIGNED
# 80     204502  700276           HIPPOGRIFFE      SIGNED
# 81     203984  709129            5HT-DREADD      SIGNED
# 92     202716  701007               TankRob      SIGNED
# 93     201358  705705            ANCHOR E3s      SIGNED
# 94     201455  706741                  BWBN      SIGNED
# 104    201076  702750                QLO-QG      SIGNED
# 106    197893  658217  low Pt loading FCCHP      SIGNED
# 107    198154  636458            CogSoCoAGE      SIGNED
# 109    199155  687655             2-IMMERSE      SIGNED
# 110    198475  669237             Oligomers      SIGNED
# 115    198064  647835               EUDEMOS      SIGNED
# 126    196814  641931               CENTAUR      SIGNED
# 130    197352  671705              SPEED-5G      SIGNED
# 133    196859  647969           ENERCAPSULE      SIGNED
# 138    197533  670726                  TVOF      SIGNED
# 149    195308  656647          MicroEcoEvol      SIGNED
# 158    193422  636811              FracRisk      SIGNED
# 159    193278  634201                 MOCHA      SIGNED
# ...       ...     ...                   ...         ...
# 20397  205309  676835            REDOXDRUGS      SIGNED
# 20402  205552  721559                   AVA      SIGNED
# 20408  205391  721455              SAFE-FLY      SIGNED
# 20409  205466  723954               PaREGEn      SIGNED
# 20421  205365  708354                 SYNOX      SIGNED
# 20422  197089  646740                RadMag      SIGNED
# 20423  193238  633491              DOLORisk      SIGNED
# 20424  202099  696331                   QDM      SIGNED
# 20428  205230  704227    Young-Italian 2015      SIGNED
# 20433  205211  695662                  DALI      SIGNED
# 20437  205347  704807                  BEND      SIGNED
# 20439  205343  703954         transcriPTIon      SIGNED
# 20440  212618  746208             NO-STRESS      SIGNED
# 20442  205261  733542             FlexTrans      SIGNED
# 20444  212610  743278          MANANDNATURE      SIGNED
# 20445  205221  702478                TRIGEM      SIGNED
# 20451  205204  694733            Revolution      SIGNED
# 20454  212597  741707              New Chol      SIGNED
# 20455  197131  665822            QUANTEXBIO  TERMINATED
# 20470  193282  634361        nEUROSTRESSPEP      SIGNED
# 20474  205216  701397     ParaplegiaAxonsER      SIGNED
# 20480  205238  706396                E2D3S2      SIGNED
# 20483  212590  731449              ELECTROU      SIGNED
# 20484  205171  675087                 AMBER      SIGNED
# 20487  212621  746908            ORI NUMBER      SIGNED
# 20491  205225  703570                INVeST      SIGNED
# 20492  205219  702004      Operation Condor      SIGNED
# 20501  205174  675662                 QCALL      SIGNED
# 20505  205188  682574             ASSIMILES      SIGNED
# 20507  205213  700108            BORONDYKAT      SIGNED
#
#                                                programme  \
# 0                   [H2020-EU.2.1.3., H2020-EU.2.1.5.1.]
# 22                            [H2020-EU.3., H2020-EU.2.]
# 24                                     [H2020-EU.1.3.2.]
# 28                                     [H2020-EU.1.3.2.]
# 30                                     [H2020-EU.1.3.2.]
# 36                                   [H2020-EU.2.3.2.2.]
# 39                                       [H2020-EU.1.1.]
# 50                                     [H2020-EU.2.1.1.]
# 59                                     [H2020-EU.1.3.2.]
# 66                                     [H2020-EU.1.3.2.]
# 73                                   [H2020-EU.3.4.8.5.]
# 78                                     [H2020-EU.1.3.2.]
# 80                                     [H2020-EU.1.3.2.]
# 81                                     [H2020-EU.1.3.2.]
# 92                            [H2020-EU.3., H2020-EU.2.]
# 93                                     [H2020-EU.1.3.2.]
# 94                                     [H2020-EU.1.3.2.]
# 104                                    [H2020-EU.1.3.2.]
# 106                                    [H2020-EU.1.3.2.]
# 107                                      [H2020-EU.1.1.]
# 109                                    [H2020-EU.2.1.1.]
# 110                                      [H2020-EU.1.1.]
# 115                                      [H2020-EU.1.1.]
# 126                                    [H2020-EU.3.5.4.]
# 130                                  [H2020-EU.2.1.1.3.]
# 133                                      [H2020-EU.1.1.]
# 138                                      [H2020-EU.1.1.]
# 149                                    [H2020-EU.1.3.2.]
# 158                                  [H2020-EU.3.3.2.3.]
# 159                                    [H2020-EU.3.1.6.]
# ...                                                  ...
# 20397                                    [H2020-EU.1.1.]
# 20402                                  [H2020-EU.1.3.1.]
# 20408                                  [H2020-EU.1.3.1.]
# 20409                                    [H2020-EU.3.4.]
# 20421                                  [H2020-EU.1.3.2.]
# 20422                                    [H2020-EU.1.1.]
# 20423                                  [H2020-EU.3.1.1.]
# 20424                                  [H2020-EU.1.3.2.]
# 20428                                  [H2020-EU.1.3.2.]
# 20433                                    [H2020-EU.1.1.]
# 20437                                  [H2020-EU.1.3.2.]
# 20439                                  [H2020-EU.1.3.2.]
# 20440                                  [H2020-EU.1.3.2.]
# 20442  [H2020-EU.2.1.5., H2020-EU.2.1.3., H2020-EU.2....
# 20444                                    [H2020-EU.1.1.]
# 20445                                  [H2020-EU.1.3.2.]
# 20451                                    [H2020-EU.1.1.]
# 20454                                    [H2020-EU.1.1.]
# 20455                                  [H2020-EU.1.3.4.]
# 20470                                    [H2020-EU.3.2.]
# 20474                                  [H2020-EU.1.3.2.]
# 20480                                  [H2020-EU.1.3.2.]
# 20483                                [H2020-EU.3.3.8.1.]
# 20484                                  [H2020-EU.1.3.1.]
# 20487                                  [H2020-EU.1.3.2.]
# 20491                                  [H2020-EU.1.3.2.]
# 20492                                  [H2020-EU.1.3.2.]
# 20501                                  [H2020-EU.1.3.1.]
# 20505                                    [H2020-EU.1.1.]
# 20507                                  [H2020-EU.1.3.2.]
#
#                      topics frameworkProgramme  \
# 0           DT-NMBP-20-2018              H2020
# 22         FTIPilot-01-2016              H2020
# 24             MSCA-IF-2016              H2020
# 28             MSCA-IF-2016              H2020
# 30             MSCA-IF-2016              H2020
# 36          INNOSUP-02-2016              H2020
# 39             ERC-2016-STG              H2020
# 50         ICT-14-2016-2017              H2020
# 59          MSCA-IF-2015-EF              H2020
# 66          MSCA-IF-2015-GF              H2020
# 73       S2R-OC-IP5-03-2015              H2020
# 78          MSCA-IF-2015-EF              H2020
# 80          MSCA-IF-2015-EF              H2020
# 81          MSCA-IF-2015-EF              H2020
# 92          FTIPilot-1-2015              H2020
# 93          MSCA-IF-2015-EF              H2020
# 94          MSCA-IF-2015-EF              H2020
# 104         MSCA-IF-2015-EF              H2020
# 106         MSCA-IF-2014-EF              H2020
# 107            ERC-StG-2014              H2020
# 109             ICT-19-2015              H2020
# 110            ERC-ADG-2014              H2020
# 115            ERC-CoG-2014              H2020
# 126           WATER-1a-2014              H2020
# 130             ICT-14-2014              H2020
# 133            ERC-CoG-2014              H2020
# 138            ERC-ADG-2014              H2020
# 149         MSCA-IF-2014-GF              H2020
# 158             LCE-16-2014              H2020
# 159             PHC-23-2014              H2020
# ...                     ...                ...
# 20397          ERC-PoC-2015              H2020
# 20402         MSCA-ITN-2016              H2020
# 20408         MSCA-ITN-2016              H2020
# 20409            GV-02-2016              H2020
# 20421       MSCA-IF-2015-EF              H2020
# 20422          ERC-CoG-2014              H2020
# 20423           PHC-01-2014              H2020
# 20424       MSCA-IF-2015-EF              H2020
# 20428       MSCA-IF-2015-EF              H2020
# 20433          ERC-ADG-2015              H2020
# 20437       MSCA-IF-2015-EF              H2020
# 20439       MSCA-IF-2015-EF              H2020
# 20440          MSCA-IF-2016              H2020
# 20442  SMEInst-02-2016-2017              H2020
# 20444          ERC-2016-ADG              H2020
# 20445       MSCA-IF-2015-EF              H2020
# 20451          ERC-ADG-2015              H2020
# 20454          ERC-2016-ADG              H2020
# 20455   MSCA-COFUND-2014-DP              H2020
# 20470          SFS-03a-2014              H2020
# 20474       MSCA-IF-2015-EF              H2020
# 20480       MSCA-IF-2015-EF              H2020
# 20483        FCH-02-11-2016              H2020
# 20484     MSCA-ITN-2015-ETN              H2020
# 20487          MSCA-IF-2016              H2020
# 20491       MSCA-IF-2015-EF              H2020
# 20492       MSCA-IF-2015-GF              H2020
# 20501     MSCA-ITN-2015-ETN              H2020
# 20505          ERC-CoG-2015              H2020
# 20507       MSCA-IF-2015-EF              H2020
#
#                                                    title  startDate  \
# 0      Digital Dynamic Knowledge Platform for Welding... 2018-10-01
# 22     A rapid, non-invasive, cost-effective, analyti... 2017-05-01
# 24     Ultra-robust, flexible organic sensors for app... 2017-07-01
# 28     Molecular Foundation of Structural and Dynamic... 2017-03-01
# 30     Breast cancer stem-like cells specific vulnera... 2017-03-01
# 36                 Get on top of your multimedia content 2017-09-01
# 39     Authority and Innovation in Early Franciscan T... 2017-01-01
# 50     QROWD - Because Big Data Integration is Humanl... 2016-12-01
# 59     Multimodal preclinical imaging probes to evalu... 2016-08-01
# 66     How to help the hive? Incidence and impact of ... 2016-10-01
# 73     INNOvative monitoring and predictive maintenan... 2016-11-01
# 78     Fishing in the dark: unravelling the global tr... 2016-07-04
# 80     Hybrid simulations of flow properties using at... 2016-07-01
# 81     In vivo pharmacogenetic investigation of 5-HT ... 2016-07-01
# 92     In-service intrusive Non-Destructive Testing o... 2016-05-01
# 93     Anchoring ligandable binding sites at E3 ligas... 2016-08-01
# 94     Black Women/Black Nationalism â Feminist Dis... 2016-08-01
# 104           Quasi-local observables in quantum gravity 2016-07-01
# 106    Innovative fuel cell system for CHP applicatio... 2016-07-01
# 107    Tracking the cognitive basis of social communi... 2015-09-01
# 109    Creating and Delivering Shared and Personalise... 2015-12-01
# 110    Characterising protein oligomers and their rol... 2015-09-01
# 115    Constrained Democracy: Citizensâ Responses t... 2015-09-01
# 126    Cost Effective Neural Technique for Alleviatio... 2015-09-01
# 130    quality of Service Provision and capacity Expa... 2015-07-01
# 133    Nanoencapsulation for Energy Storage and Contr... 2015-09-01
# 138    The values of French language and literature i... 2015-09-01
# 149    Ecological and evolutionary forces shaping mic... 2015-06-01
# 158    Furthering the Knowledge Base For Reducing the... 2015-06-01
# 159                     Models of Child Health Appraised 2015-06-01
# ...                                                  ...        ...
# 20397  Discovery and commercialisation of novel compo... 2016-09-01
# 20402         Accelerators Validating Antimatter physics 2017-01-01
# 20408  European industrial doctorate for damage model... 2017-01-01
# 20409       Particle Reduced, Efficient Gasoline Engines 2016-10-01
# 20421  Total Synthesis of Biologically Important Pyrr... 2016-09-01
# 20422  Radical Solutions for Hysteresis in Single-Mol... 2015-09-01
# 20423  DOLORisk: Understanding risk factors and deter... 2015-07-01
# 20424                            Quantum Decision Making 2016-10-01
# 20428  Dangerous Masculinities: Young Men in Italian ... 2016-11-01
# 20433          Disagreements and Language Interpretation 2016-09-01
# 20437  Bendable Bioplatform for Electrically stimulat... 2016-08-15
# 20439  Understanding transcriptional regulation in pl... 2016-09-21
# 20440  Nitric oxide regulation of repolarisation in t... 2018-10-31
# 20442  a universal thin film transistor platform for ... 2016-09-01
# 20444             Man and Nature in Developing Countries 2017-12-01
# 20445  Unlocking Triterpenoid Structural Diversity an... 2016-10-01
# 20451      Regulation and Evolution of C4 photosynthesis 2016-09-01
# 20454  Development of New therapies against cholangio... 2017-12-01
# 20455              Quantitative and Experimental Biology 2015-11-01
# 20470  Novel biocontrol agents for insect pests from ... 2015-06-01
# 20474  Functional interactions between endoplasmic re... 2017-03-01
# 20480  Education and Engagement for inclusive Design ... 2016-10-01
# 20483  MW Fuel Cell micro grid and district heating a... 2018-01-01
# 20484                 AMBER - enhAnced Mobile BiomEtRics 2017-01-01
# 20487  Unravelling the effect of origin number on the... 2017-12-01
# 20491  INdividual Vascular SignaTure: A new machine l... 2016-09-01
# 20492  Operation Condor: Accountability for Transnati... 2016-08-01
# 20501                     Quantum Communications for ALL 2016-12-01
# 20505  Advanced Spectroscopy and Spectrometry for Ima... 2016-09-01
# 20507  VINYL AND HETEROARYL BORONIC ACIDS AS NON-STAB... 2016-08-01
#
#          endDate   ...     fundingScheme  \
# 0     2022-03-31   ...             IA-LS
# 22    2019-04-30   ...                IA
# 24    2019-06-30   ...        MSCA-IF-GF
# 28    2019-02-28   ...     MSCA-IF-EF-ST
# 30    2019-02-28   ...     MSCA-IF-EF-RI
# 36    2018-08-31   ...               CSA
# 39    2021-12-31   ...           ERC-STG
# 50    2019-11-30   ...                IA
# 59    2018-07-31   ...     MSCA-IF-EF-ST
# 66    2019-05-31   ...        MSCA-IF-GF
# 73    2019-04-30   ...    Shift2Rail-RIA
# 78    2018-07-03   ...     MSCA-IF-EF-ST
# 80    2018-06-30   ...     MSCA-IF-EF-ST
# 81    2018-06-30   ...     MSCA-IF-EF-ST
# 92    2018-10-31   ...                IA
# 93    2018-07-31   ...     MSCA-IF-EF-ST
# 94    2018-07-31   ...     MSCA-IF-EF-ST
# 104   2018-06-30   ...     MSCA-IF-EF-ST
# 106   2018-06-30   ...     MSCA-IF-EF-ST
# 107   2020-08-31   ...           ERC-STG
# 109   2018-11-30   ...                IA
# 110   2020-08-31   ...           ERC-ADG
# 115   2020-08-31   ...           ERC-COG
# 126   2018-08-31   ...                IA
# 130   2018-03-31   ...               RIA
# 133   2020-08-31   ...           ERC-COG
# 138   2020-08-31   ...           ERC-ADG
# 149   2018-05-31   ...        MSCA-IF-GF
# 158   2018-05-31   ...               RIA
# 159   2018-11-30   ...               RIA
# ...          ...   ...               ...
# 20397 2018-02-28   ...           ERC-POC
# 20402 2020-12-31   ...      MSCA-ITN-ETN
# 20408 2020-12-31   ...      MSCA-ITN-EID
# 20409 2019-09-30   ...               RIA
# 20421 2018-08-31   ...     MSCA-IF-EF-ST
# 20422 2020-08-31   ...           ERC-COG
# 20423 2019-06-30   ...               RIA
# 20424 2018-09-30   ...     MSCA-IF-EF-ST
# 20428 2018-10-31   ...     MSCA-IF-EF-ST
# 20433 2021-08-31   ...           ERC-ADG
# 20437 2018-08-14   ...     MSCA-IF-EF-ST
# 20439 2018-09-20   ...     MSCA-IF-EF-ST
# 20440 2020-10-30   ...     MSCA-IF-EF-ST
# 20442 2018-08-31   ...             SME-2
# 20444 2022-11-30   ...           ERC-ADG
# 20445 2018-09-30   ...     MSCA-IF-EF-ST
# 20451 2021-08-31   ...           ERC-ADG
# 20454 2022-11-30   ...           ERC-ADG
# 20455 2020-10-31   ...    MSCA-COFUND-DP
# 20470 2019-05-31   ...               RIA
# 20474 2019-02-28   ...     MSCA-IF-EF-ST
# 20480 2018-09-30   ...     MSCA-IF-EF-ST
# 20483 2023-06-30   ...           FCH2-IA
# 20484 2020-12-31   ...      MSCA-ITN-ETN
# 20487 2019-11-30   ...     MSCA-IF-EF-ST
# 20491 2018-08-31   ...     MSCA-IF-EF-ST
# 20492 2019-07-31   ...        MSCA-IF-GF
# 20501 2020-11-30   ...      MSCA-ITN-ETN
# 20505 2021-08-31   ...           ERC-COG
# 20507 2018-07-31   ...     MSCA-IF-EF-ST
#
#                                              coordinator  coordinatorCountry  \
# 0                                            TWI LIMITED                  UK
# 22                            IMSPEX DIAGNOSTICS LIMITED                  UK
# 24     THE CHANCELLOR MASTERS AND SCHOLARS OF THE UNI...                  UK
# 28     THE CHANCELLOR MASTERS AND SCHOLARS OF THE UNI...                  UK
# 30                     UNIVERSITY OF NEWCASTLE UPON TYNE                  UK
# 36             IN2 SEARCH INTERFACES DEVELOPMENT LIMITED                  UK
# 39                                 KING'S COLLEGE LONDON                  UK
# 50                             UNIVERSITY OF SOUTHAMPTON                  UK
# 59                           THE UNIVERSITY OF LIVERPOOL                  UK
# 66                           THE UNIVERSITY OF LIVERPOOL                  UK
# 73                     UNIVERSITY OF NEWCASTLE UPON TYNE                  UK
# 78                             THE UNIVERSITY OF SALFORD                  UK
# 80                       QUEEN MARY UNIVERSITY OF LONDON                  UK
# 81     THE CHANCELLOR, MASTERS AND SCHOLARS OF THE UN...                  UK
# 92     INNOVATIVE TECHNOLOGY AND SCIENCE LIMITED - IN...                  UK
# 93                                  UNIVERSITY OF DUNDEE                  UK
# 94                      UNIVERSITY OF CENTRAL LANCASHIRE                  UK
# 104                                   UNIVERSITY OF YORK                  UK
# 106                         THE UNIVERSITY OF NOTTINGHAM                  UK
# 107                                   UNIVERSITY OF KENT                  UK
# 109                     BRITISH BROADCASTING CORPORATION                  UK
# 110    THE CHANCELLOR MASTERS AND SCHOLARS OF THE UNI...                  UK
# 115     LONDON SCHOOL OF ECONOMICS AND POLITICAL SCIENCE                  UK
# 126                          THE UNIVERSITY OF SHEFFIELD                  UK
# 130                                 UNIVERSITY OF SURREY                  UK
# 133                          THE UNIVERSITY OF LIVERPOOL                  UK
# 138                                KING'S COLLEGE LONDON                  UK
# 149                             THE UNIVERSITY OF EXETER                  UK
# 158                          THE UNIVERSITY OF EDINBURGH                  UK
# 159    IMPERIAL COLLEGE OF SCIENCE TECHNOLOGY AND MED...                  UK
# ...                                                  ...                 ...
# 20397  THE CHANCELLOR MASTERS AND SCHOLARS OF THE UNI...                  UK
# 20402                        THE UNIVERSITY OF LIVERPOOL                  UK
# 20408                       THE UNIVERSITY OF NOTTINGHAM                  UK
# 20409                                 RICARDO UK LIMITED                  UK
# 20421  THE CHANCELLOR, MASTERS AND SCHOLARS OF THE UN...                  UK
# 20422                       THE UNIVERSITY OF MANCHESTER                  UK
# 20423  THE CHANCELLOR, MASTERS AND SCHOLARS OF THE UN...                  UK
# 20424                          CITY UNIVERSITY OF LONDON                  UK
# 20428                              UNIVERSITY OF BRISTOL                  UK
# 20433                    QUEEN MARY UNIVERSITY OF LONDON                  UK
# 20437                              UNIVERSITY OF GLASGOW                  UK
# 20439                           THE SAINSBURY LABORATORY                  UK
# 20440  THE CHANCELLOR, MASTERS AND SCHOLARS OF THE UN...                  UK
# 20442                                   SMARTKEM LIMITED                  UK
# 20444   LONDON SCHOOL OF ECONOMICS AND POLITICAL SCIENCE                  UK
# 20445                                  JOHN INNES CENTRE                  UK
# 20451  THE CHANCELLOR MASTERS AND SCHOLARS OF THE UNI...                  UK
# 20454  THE CHANCELLOR MASTERS AND SCHOLARS OF THE UNI...                  UK
# 20455                               UNIVERSITY OF DUNDEE                  UK
# 20470                              UNIVERSITY OF GLASGOW                  UK
# 20474  THE CHANCELLOR MASTERS AND SCHOLARS OF THE UNI...                  UK
# 20480                                 UNIVERSITY OF YORK                  UK
# 20483                  METROPOLITAN KING'S CROSS LIMITED                  UK
# 20484                                 UNIVERSITY OF KENT                  UK
# 20487                               UNIVERSITY OF DUNDEE                  UK
# 20491                                   ASTON UNIVERSITY                  UK
# 20492  THE CHANCELLOR, MASTERS AND SCHOLARS OF THE UN...                  UK
# 20501                                UNIVERSITY OF LEEDS                  UK
# 20505  THE CHANCELLOR MASTERS AND SCHOLARS OF THE UNI...                  UK
# 20507  THE CHANCELLOR, MASTERS AND SCHOLARS OF THE UN...                  UK
#
#                                             participants  \
# 0      [LULEA TEKNISKA UNIVERSITET, ROMSOFT SRL, TECH...
# 22     [REDKNIGHT CONSULTANCY LTD, THE UNIVERSITY OF ...
# 24                                                   NaN
# 28                                                   NaN
# 30                                                   NaN
# 36                                                   NaN
# 39     [CENTRE NATIONAL DE LA RECHERCHE SCIENTIFIQUE ...
# 50     [COMUNE DI TRENTO, INMARK EUROPA SA, TOMTOM DE...
# 59                                                   NaN
# 66                                                   NaN
# 73     [Inertia Technology B.V., UNION DES INDUSTRIES...
# 78                                                   NaN
# 80                                                   NaN
# 81                                                   NaN
# 92     [TECHNIC CONTROL, LONDON SOUTH BANK UNIVERSITY...
# 93                                                   NaN
# 94                                                   NaN
# 104                                                  NaN
# 106                                                  NaN
# 107                                                  NaN
# 109    [ChyronHego AB, STICHTING CENTRUM VOOR WISKUND...
# 110                                                  NaN
# 115                                                  NaN
# 126    [VEOLIA WATER OUTSOURCING LIMITED, VEOLIA EAU ...
# 130    [SISTELBANDA SA, INSTITUTO DE TELECOMUNICACOES...
# 133                                                  NaN
# 138                                                  NaN
# 149                                                  NaN
# 158    [UNIVERSITAT WIEN, JUNG-GEOTHERM UG, GEORG-AUG...
# 159    [UNIVERSITY OF KEELE, UNIVERSITETET I TROMSOE,...
# ...                                                  ...
# 20397                                                NaN
# 20402  [COSYLAB LABORATORIJ ZA KONTROLNE SISTEME DD, ...
# 20408                [AERNNOVA ENGINEERING DIVISION SAU]
# 20409  [ROBERT BOSCH GMBH, RHEINISCH-WESTFAELISCHE TE...
# 20421                                                NaN
# 20422                   [KATHOLIEKE UNIVERSITEIT LEUVEN]
# 20423  [AARHUS UNIVERSITET, INSTITUT NATIONAL DE LA S...
# 20424                                                NaN
# 20428                                                NaN
# 20433                              [UNIVERSITY OF ESSEX]
# 20437                                                NaN
# 20439                                                NaN
# 20440                                                NaN
# 20442                                                NaN
# 20444                                                NaN
# 20445                                                NaN
# 20451                                                NaN
# 20454                                                NaN
# 20455                                                NaN
# 20470  [BRUKER DALTONIK GMBH, UNIVERSITEIT GENT, FORE...
# 20474                                                NaN
# 20480                                                NaN
# 20483  [FUELCELL ENERGY SOLUTIONS GMBH, FUEL CELL SYS...
# 20484  [OTTO-VON-GUERICKE-UNIVERSITAET MAGDEBURG, UNI...
# 20487                                                NaN
# 20491                                                NaN
# 20492                                                NaN
# 20501  [UNIVERSITE PIERRE ET MARIE CURIE - PARIS 6, H...
# 20505                                                NaN
# 20507                                                NaN
#
#                                     participantCountries subjects  \
# 0                       [SE, RO, UK, NO, PL, FR, IL, ES]      NaN
# 22                                          [UK, IE, DE]      NaN
# 24                                                   NaN      NaN
# 28                                                   NaN      NaN
# 30                                                   NaN      NaN
# 36                                                   NaN      NaN
# 39                                                  [FR]      NaN
# 50                                      [IT, ES, DE, CH]      NaN
# 59                                                   NaN      NaN
# 66                                                   NaN      NaN
# 73                          [NL, BE, DE, RO, CZ, IT, UK]      NaN
# 78                                                   NaN      NaN
# 80                                                   NaN      NaN
# 81                                                   NaN      NaN
# 92                                          [PL, UK, TR]      NaN
# 93                                                   NaN      NaN
# 94                                                   NaN      NaN
# 104                                                  NaN      NaN
# 106                                                  NaN      NaN
# 107                                                  NaN      NaN
# 109                                     [SE, NL, DE, UK]      NaN
# 110                                                  NaN      NaN
# 115                                                  NaN      NaN
# 126                                 [UK, FR, CH, PT, DE]      NaN
# 130                             [ES, PT, EL, FR, DE, UK]      NaN
# 133                                                  NaN      NaN
# 138                                                  NaN      NaN
# 149                                                  NaN      NaN
# 158                     [AT, DE, SE, ES, UK, IT, FR, IL]      NaN
# 159    [UK, NO, CY, IE, NL, PL, CH, IT, US, DK, AU, S...      NaN
# ...                                                  ...      ...
# 20397                                                NaN      NaN
# 20402                           [SI, UK, DE, CZ, CH, AT]      NaN
# 20408                                               [ES]      NaN
# 20409           [DE, FR, ES, UK, NL, CH, IT, CZ, SE, BE]      NaN
# 20421                                                NaN      NaN
# 20422                                               [BE]      NaN
# 20423               [DK, FR, UK, BE, DE, IS, ES, IL, SE]      NaN
# 20424                                                NaN      NaN
# 20428                                                NaN      NaN
# 20433                                               [UK]      NaN
# 20437                                                NaN      NaN
# 20439                                                NaN      NaN
# 20440                                                NaN      NaN
# 20442                                                NaN      NaN
# 20444                                                NaN      NaN
# 20445                                                NaN      NaN
# 20451                                                NaN      NaN
# 20454                                                NaN      NaN
# 20455                                                NaN      NaN
# 20470                           [DE, BE, UK, IL, ZA, SE]      NaN
# 20474                                                NaN      NaN
# 20480                                                NaN      NaN
# 20483                                       [DE, UK, IT]      NaN
# 20484                                   [DE, IT, PL, ES]      NaN
# 20487                                                NaN      NaN
# 20491                                                NaN      NaN
# 20492                                                NaN      NaN
# 20501                           [FR, DE, CH, IT, UK, ES]      NaN
# 20505                                                NaN      NaN
# 20507                                                NaN      NaN
#
#                                            organisations  \
# 0      [TWI LIMITED, LULEA TEKNISKA UNIVERSITET, ROMS...
# 22     [IMSPEX DIAGNOSTICS LIMITED, REDKNIGHT CONSULT...
# 24     [THE CHANCELLOR MASTERS AND SCHOLARS OF THE UN...
# 28     [THE CHANCELLOR MASTERS AND SCHOLARS OF THE UN...
# 30                   [UNIVERSITY OF NEWCASTLE UPON TYNE]
# 36           [IN2 SEARCH INTERFACES DEVELOPMENT LIMITED]
# 39     [KING'S COLLEGE LONDON, CENTRE NATIONAL DE LA ...
# 50     [UNIVERSITY OF SOUTHAMPTON, COMUNE DI TRENTO, ...
# 59                         [THE UNIVERSITY OF LIVERPOOL]
# 66                         [THE UNIVERSITY OF LIVERPOOL]
# 73     [UNIVERSITY OF NEWCASTLE UPON TYNE, Inertia Te...
# 78                           [THE UNIVERSITY OF SALFORD]
# 80                     [QUEEN MARY UNIVERSITY OF LONDON]
# 81     [THE CHANCELLOR, MASTERS AND SCHOLARS OF THE U...
# 92     [INNOVATIVE TECHNOLOGY AND SCIENCE LIMITED - I...
# 93                                [UNIVERSITY OF DUNDEE]
# 94                    [UNIVERSITY OF CENTRAL LANCASHIRE]
# 104                                 [UNIVERSITY OF YORK]
# 106                       [THE UNIVERSITY OF NOTTINGHAM]
# 107                                 [UNIVERSITY OF KENT]
# 109    [BRITISH BROADCASTING CORPORATION, ChyronHego ...
# 110    [THE CHANCELLOR MASTERS AND SCHOLARS OF THE UN...
# 115    [LONDON SCHOOL OF ECONOMICS AND POLITICAL SCIE...
# 126    [THE UNIVERSITY OF SHEFFIELD, VEOLIA WATER OUT...
# 130    [UNIVERSITY OF SURREY, SISTELBANDA SA, INSTITU...
# 133                        [THE UNIVERSITY OF LIVERPOOL]
# 138                              [KING'S COLLEGE LONDON]
# 149                           [THE UNIVERSITY OF EXETER]
# 158    [THE UNIVERSITY OF EDINBURGH, UNIVERSITAT WIEN...
# 159    [IMPERIAL COLLEGE OF SCIENCE TECHNOLOGY AND ME...
# ...                                                  ...
# 20397  [THE CHANCELLOR MASTERS AND SCHOLARS OF THE UN...
# 20402  [THE UNIVERSITY OF LIVERPOOL, COSYLAB LABORATO...
# 20408  [THE UNIVERSITY OF NOTTINGHAM, AERNNOVA ENGINE...
# 20409  [RICARDO UK LIMITED, ROBERT BOSCH GMBH, RHEINI...
# 20421  [THE CHANCELLOR, MASTERS AND SCHOLARS OF THE U...
# 20422  [THE UNIVERSITY OF MANCHESTER, KATHOLIEKE UNIV...
# 20423  [THE CHANCELLOR, MASTERS AND SCHOLARS OF THE U...
# 20424                        [CITY UNIVERSITY OF LONDON]
# 20428                            [UNIVERSITY OF BRISTOL]
# 20433  [QUEEN MARY UNIVERSITY OF LONDON, UNIVERSITY O...
# 20437                            [UNIVERSITY OF GLASGOW]
# 20439                         [THE SAINSBURY LABORATORY]
# 20440  [THE CHANCELLOR, MASTERS AND SCHOLARS OF THE U...
# 20442                                 [SMARTKEM LIMITED]
# 20444  [LONDON SCHOOL OF ECONOMICS AND POLITICAL SCIE...
# 20445                                [JOHN INNES CENTRE]
# 20451  [THE CHANCELLOR MASTERS AND SCHOLARS OF THE UN...
# 20454  [THE CHANCELLOR MASTERS AND SCHOLARS OF THE UN...
# 20455                             [UNIVERSITY OF DUNDEE]
# 20470  [UNIVERSITY OF GLASGOW, BRUKER DALTONIK GMBH, ...
# 20474  [THE CHANCELLOR MASTERS AND SCHOLARS OF THE UN...
# 20480                               [UNIVERSITY OF YORK]
# 20483  [METROPOLITAN KING'S CROSS LIMITED, FUELCELL E...
# 20484  [UNIVERSITY OF KENT, OTTO-VON-GUERICKE-UNIVERS...
# 20487                             [UNIVERSITY OF DUNDEE]
# 20491                                 [ASTON UNIVERSITY]
# 20492  [THE CHANCELLOR, MASTERS AND SCHOLARS OF THE U...
# 20501  [UNIVERSITY OF LEEDS, UNIVERSITE PIERRE ET MAR...
# 20505  [THE CHANCELLOR MASTERS AND SCHOLARS OF THE UN...
# 20507  [THE CHANCELLOR, MASTERS AND SCHOLARS OF THE U...
#
#                                                countries startYear endYear
# 0                   [UK, SE, RO, UK, NO, PL, FR, IL, ES]    2018.0  2022.0
# 22                                      [UK, UK, IE, DE]    2017.0  2019.0
# 24                                                  [UK]    2017.0  2019.0
# 28                                                  [UK]    2017.0  2019.0
# 30                                                  [UK]    2017.0  2019.0
# 36                                                  [UK]    2017.0  2018.0
# 39                                              [UK, FR]    2017.0  2021.0
# 50                                  [UK, IT, ES, DE, CH]    2016.0  2019.0
# 59                                                  [UK]    2016.0  2018.0
# 66                                                  [UK]    2016.0  2019.0
# 73                      [UK, NL, BE, DE, RO, CZ, IT, UK]    2016.0  2019.0
# 78                                                  [UK]    2016.0  2018.0
# 80                                                  [UK]    2016.0  2018.0
# 81                                                  [UK]    2016.0  2018.0
# 92                                      [UK, PL, UK, TR]    2016.0  2018.0
# 93                                                  [UK]    2016.0  2018.0
# 94                                                  [UK]    2016.0  2018.0
# 104                                                 [UK]    2016.0  2018.0
# 106                                                 [UK]    2016.0  2018.0
# 107                                                 [UK]    2015.0  2020.0
# 109                                 [UK, SE, NL, DE, UK]    2015.0  2018.0
# 110                                                 [UK]    2015.0  2020.0
# 115                                                 [UK]    2015.0  2020.0
# 126                             [UK, UK, FR, CH, PT, DE]    2015.0  2018.0
# 130                         [UK, ES, PT, EL, FR, DE, UK]    2015.0  2018.0
# 133                                                 [UK]    2015.0  2020.0
# 138                                                 [UK]    2015.0  2020.0
# 149                                                 [UK]    2015.0  2018.0
# 158                 [UK, AT, DE, SE, ES, UK, IT, FR, IL]    2015.0  2018.0
# 159    [UK, UK, NO, CY, IE, NL, PL, CH, IT, US, DK, A...    2015.0  2018.0
# ...                                                  ...       ...     ...
# 20397                                               [UK]    2016.0  2018.0
# 20402                       [UK, SI, UK, DE, CZ, CH, AT]    2017.0  2020.0
# 20408                                           [UK, ES]    2017.0  2020.0
# 20409       [UK, DE, FR, ES, UK, NL, CH, IT, CZ, SE, BE]    2016.0  2019.0
# 20421                                               [UK]    2016.0  2018.0
# 20422                                           [UK, BE]    2015.0  2020.0
# 20423           [UK, DK, FR, UK, BE, DE, IS, ES, IL, SE]    2015.0  2019.0
# 20424                                               [UK]    2016.0  2018.0
# 20428                                               [UK]    2016.0  2018.0
# 20433                                           [UK, UK]    2016.0  2021.0
# 20437                                               [UK]    2016.0  2018.0
# 20439                                               [UK]    2016.0  2018.0
# 20440                                               [UK]    2018.0  2020.0
# 20442                                               [UK]    2016.0  2018.0
# 20444                                               [UK]    2017.0  2022.0
# 20445                                               [UK]    2016.0  2018.0
# 20451                                               [UK]    2016.0  2021.0
# 20454                                               [UK]    2017.0  2022.0
# 20455                                               [UK]    2015.0  2020.0
# 20470                       [UK, DE, BE, UK, IL, ZA, SE]    2015.0  2019.0
# 20474                                               [UK]    2017.0  2019.0
# 20480                                               [UK]    2016.0  2018.0
# 20483                                   [UK, DE, UK, IT]    2018.0  2023.0
# 20484                               [UK, DE, IT, PL, ES]    2017.0  2020.0
# 20487                                               [UK]    2017.0  2019.0
# 20491                                               [UK]    2016.0  2018.0
# 20492                                               [UK]    2016.0  2019.0
# 20501                       [UK, FR, DE, CH, IT, UK, ES]    2016.0  2020.0
# 20505                                               [UK]    2016.0  2021.0
# 20507                                               [UK]    2016.0  2018.0
#
# [3685 rows x 25 columns]

# %%
# loc iloc
#up to top 4 rows (shows rows 0,1,2,3)
cordis_projects_df.iloc[:4]

#up to index '4' (shows rows 0,1,2,3,4)
cordis_projects_df.loc[:4]

#subset of is null/not null
# Out:
#       rcn      id     acronym  status  \
# 0  218249  822106  WeldGalaxy  SIGNED
# 1  218272  822064   MARKET4.0  SIGNED
# 2  216937  816551      SCOPIO  SIGNED
# 3  218836  811181  MapProdIGI  SIGNED
# 4  218837  814729  SSH Impact  SIGNED
#
#                                      programme                 topics  \
# 0         [H2020-EU.2.1.3., H2020-EU.2.1.5.1.]        DT-NMBP-20-2018
# 1         [H2020-EU.2.1.3., H2020-EU.2.1.5.1.]        DT-NMBP-20-2018
# 2  [H2020-EU.3., H2020-EU.2.3., H2020-EU.2.1.]  EIC-SMEInst-2018-2020
# 3                          [H2020-EU.3.6.2.1.]     IBA-SC6-Nexus-2017
# 4                          [H2020-EU.3.6.2.1.]   IBA-SC6-AUSTRIA-2018
#
#   frameworkProgramme                                              title  \
# 0              H2020  Digital Dynamic Knowledge Platform for Welding...
# 1              H2020  A Multi-Sided Business Platform for Plug and P...
# 2              H2020  High-resolution, all-digital microscope that a...
# 3              H2020  Microdata analysis for Policies for Productivi...
# 4              H2020  Conference on the âImpact of Social Sciences...
#
#    startDate    endDate   ...   fundingScheme  \
# 0 2018-10-01 2022-03-31   ...           IA-LS
# 1 2018-11-01 2022-04-30   ...           IA-LS
# 2 2018-05-01 2018-08-31   ...           SME-1
# 3 2018-07-01 2021-06-30   ...             CSA
# 4 2018-03-01 2019-02-28   ...             CSA
#
#                                          coordinator  coordinatorCountry  \
# 0                                        TWI LIMITED                  UK
# 1                         INTRASOFT INTERNATIONAL SA                  BE
# 2                                    SCOPIO LABS LTD                  IL
# 3  ORGANISATION FOR ECONOMIC CO-OPERATION AND DEV...                  FR
# 4                ZENTRUM FUR SOZIALE INNOVATION GMBH                  AT
#
#                                         participants  \
# 0  [LULEA TEKNISKA UNIVERSITET, ROMSOFT SRL, TECH...
# 1  [N.BAZIGOS ABEE, NEDERLANDSE ORGANISATIE VOOR ...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                    participantCountries subjects  \
# 0      [SE, RO, UK, NO, PL, FR, IL, ES]      NaN
# 1  [EL, NL, ES, DE, IT, FR, AT, LU, LT]      NaN
# 2                                   NaN      NaN
# 3                                   NaN      NaN
# 4                                   NaN      NaN
#
#                                        organisations  \
# 0  [TWI LIMITED, LULEA TEKNISKA UNIVERSITET, ROMS...
# 1  [INTRASOFT INTERNATIONAL SA, N.BAZIGOS ABEE, N...
# 2                                  [SCOPIO LABS LTD]
# 3  [ORGANISATION FOR ECONOMIC CO-OPERATION AND DE...
# 4              [ZENTRUM FUR SOZIALE INNOVATION GMBH]
#
#                                   countries startYear endYear
# 0      [UK, SE, RO, UK, NO, PL, FR, IL, ES]    2018.0  2022.0
# 1  [BE, EL, NL, ES, DE, IT, FR, AT, LU, LT]    2018.0  2022.0
# 2                                      [IL]    2018.0  2018.0
# 3                                      [FR]    2018.0  2021.0
# 4                                      [AT]    2018.0  2019.0
#
# [5 rows x 25 columns]

# %%
# cordis_projects_df

# %%
# loc based on the name of labels in index
# iloc based on position in index

# %% [markdown]
# # Data Wrangling

# %% [markdown]
# ## Cleaning

# %% [markdown]
# ### Dropping Data

# %%
# drop columns (a list of column names or single!)
df.drop(columns, inplace=True, axis=1)

# %%
# drop rows 
df.drop(rows, inplace=True, axis=0)

# %% [markdown]
# ## Handling Missing Data

# %% [markdown]
# Descriptions

# %%
# another way to drop columns where all elements are nan
#use toy here
df.dropna(axis = 1, how='any')

# %%
# another way to drop rows where all elements are nan; here axis =0 by default
df.dropna(how='any')

# %% [markdown]
# There are other `how` parameter options. See what happens when `how` equals `all`

# %% [markdown]
# Drop duplicates (rows)

# %%
df.drop_duplicates()

#can drop duplicates based on one column 
df.drop_duplicates(subset="col", inplace=True)

# %% [markdown]
# filter(using conditons)

# %% [markdown]
# ## Rename & Resets

# %%
# renaming columns
# reset index

# %% [markdown]
# ## Tranformation

# %%
# add new columns
cordis_projects_df['half_totalCost'] = cordis_projects_df['totalCost'] * 0.5
#group data & apply a function & mergeb
#refer back to adat types and how we change datatype of column

# %%
#transpose data

df.T

# %% [markdown]
# ### Mapping

# %%
#dcitionary

# %%
#

# %% [markdown]
# ### GroupBy

# %%
#preferable group by categorical -type column
grouped_df = cordis_projects_df.groupby(by=['status', 'ecMaxContribution'])

# %% [markdown]
# Here, we can investigate statistical results of each numerical column based on the groups defined by applying the methods form earlier.

# %%
grouped_df.mean()

# %%
grouped_df.sum()

# %%
# can replace values 
#avoid lambda- use numpy funtion instead
grouped_df['totalCost'].apply(lambda x: x/x.count()) #divided by the count of the grouped

# %%
cordis_projects_df.head()

# %%
# can groupby on different levels and cal on diff levels

# %%
#careful cos some columns may have integers but are IDs 
#so up to you to make decision what to do with it

# %% [markdown]
# # Working with DateTime
# <br />
# In a lot of cases, datetime information are stored as strings. Thankfully, pandas can deal with this.

# %% [markdown]
# # Combining Data

# %% [markdown]
# Firtsly, let's define another toy example.

# %%
df_2= pd.DataFrame(
    {
        'col1': ['a', 'b', 1, 2], 
        'col2': ['d', 'e', 'f', 'k'], 
        'col3': [5, 6, 7, 8],
        'col4': ['h', 'i', 'j', 'k']
    }

)

# %%
df_1
# Out:
#    col1 col2  col3  col4
# 0     a    d   1.0     4
# 1     b    e   2.0     5
# 2  None    f   3.0     6
# 3     c    g   NaN     7

# %%
df_2
# Out:
#   col1 col2  col3 col4
# 0    a    d     5    h
# 1    b    e     6    i
# 2    1    f     7    j
# 3    2    k     8    k

# %% [markdown]
# ### Merge
#
# In Pandas, there are various ways to merge: `left`, `right`, `inner`, `outer`. Here, we have to specify

# %%
# merge - `left` specifies the first is the main dataframe and the other is mergeing with it 
# note, the columns must be the same in order for a smooth merge
#note the col chosen of the chosen df of is constant and everything is depent on that (Whether it includes the lement in it's respective row)
# pd.merge(
#     df_1,
#     df_2,
#     how='left', 
#     on= 'col2'
# )

# %%
pd.merge(
    df_1,
    df_2,
    how='right', 
    on= 'col2'
)
# Out:
#   col1_x col2  col3_x  col4_x col1_y  col3_y col4_y
# 0      a    d     1.0     4.0      a       5      h
# 1      b    e     2.0     5.0      b       6      i
# 2   None    f     3.0     6.0      1       7      j
# 3    NaN    k     NaN     NaN      2       8      k

# %%
#intersection/elements of col2 which appears in both cols 
pd.merge(
    df_1,
    df_2,
    how='inner', 
    on= 'col2'
)

# %%
#union 
pd.merge(
    df_1,
    df_2,
    how='outer', 
    on= 'col2'
)

#left_on right_on (column with diff names)

# %%
# join- works similarly but automatically recognises where/ dont need to define

df_1.join(df_2, 'col2', how='right')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-136d74f57eca> in <module>
#       1 # join- works similarly but automatically recognises where/ dont need to define
#       2
# ----> 3 df_1.join(df_2, 'col2', how='right')
#
# ~/miniconda3/envs/pyenv_nesta/lib/python3.6/site-packages/pandas/core/frame.py in join(self, other, on, how, lsuffix, rsuffix, sort)
#    6334         # For SparseDataFrame's benefit
#    6335         return self._join_compat(other, on=on, how=how, lsuffix=lsuffix,
# -> 6336                                  rsuffix=rsuffix, sort=sort)
#    6337
#    6338     def _join_compat(self, other, on=None, how='left', lsuffix='', rsuffix='',
#
# ~/miniconda3/envs/pyenv_nesta/lib/python3.6/site-packages/pandas/core/frame.py in _join_compat(self, other, on, how, lsuffix, rsuffix, sort)
#    6349             return merge(self, other, left_on=on, how=how,
#    6350                          left_index=on is None, right_index=True,
# -> 6351                          suffixes=(lsuffix, rsuffix), sort=sort)
#    6352         else:
#    6353             if on is not None:
#
# ~/miniconda3/envs/pyenv_nesta/lib/python3.6/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      59                          right_index=right_index, sort=sort, suffixes=suffixes,
#      60                          copy=copy, indicator=indicator,
# ---> 61                          validate=validate)
#      62     return op.get_result()
#      63
#
# ~/miniconda3/envs/pyenv_nesta/lib/python3.6/site-packages/pandas/core/reshape/merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     553         # validate the merge keys dtypes. We may need to coerce
#     554         # to avoid incompat dtypes
# --> 555         self._maybe_coerce_merge_keys()
#     556
#     557         # If argument passed to validate,
#
# ~/miniconda3/envs/pyenv_nesta/lib/python3.6/site-packages/pandas/core/reshape/merge.py in _maybe_coerce_merge_keys(self)
#     984             elif (not is_numeric_dtype(lk)
#     985                     and (is_numeric_dtype(rk) and not is_bool_dtype(rk))):
# --> 986                 raise ValueError(msg)
#     987             elif is_datetimelike(lk) and not is_datetimelike(rk):
#     988                 raise ValueError(msg)
#
# ValueError: You are trying to merge on object and int64 columns. If you wish to proceed you should use pd.concat

# %%
#concatenate- in a way like stacking 
#Used to append two or more dataframes on-top or sideways 
pd.concat([df_1,df_2]) #default axis= 0

# %%
pd.concat([df_1,df_2], axis=1)# where it's concatenated in ord on

# %% [markdown]
# # Working with...
#
# Here, we will look at different non-numeric data type and how we can work with them in pandas.

# %% [markdown]
# ## DateTime
# <br />
# In a lot of cases, datetime information are stored as strings. Thankfully, pandas can deal with this. These strings are transformed to datetime objects.

# %%
#in this dataset, these dates are already datetime objects 
#write example
cordis_projects_df['startDate'] = pd.to_datetime(cordis_projects_df['startDate'])
cordis_projects_df
# Out:
#           rcn      id              acronym      status  \
# 0      218249  822106           WeldGalaxy      SIGNED
# 1      218272  822064            MARKET4.0      SIGNED
# 2      216937  816551               SCOPIO      SIGNED
# 3      218836  811181           MapProdIGI      SIGNED
# 4      218837  814729           SSH Impact      SIGNED
# 5      218833  811163               GLORIA      SIGNED
# 6      217710  816708             Biopsy X      SIGNED
# 7      217626  815751                 SIWI      SIGNED
# 8      211066  761508               5GCITY      SIGNED
# 9      215832  801051                EPEEC      SIGNED
# 10     212274  749527               MoThal  TERMINATED
# 11     213720  809174              FITT-iN      SIGNED
# 12     212504  783988            TheMotion      SIGNED
# 13     211340  778089         Smartscope-X      SIGNED
# 14     211977  778788          Hi-ThermCap      SIGNED
# 15     212163  783989           WATER4AGRI      SIGNED
# 16     211755  778764           SIADE SaaS      SIGNED
# 17     211536  778161            Uno-sport      SIGNED
# 18     211070  761557               NGPaaS      SIGNED
# 19     211469  777770           HOMEBIOGAS      SIGNED
# 20     211063  761493              5GTANGO      SIGNED
# 21     211342  768398       SocialDiabetes      SIGNED
# 22     210626  755667           BreathSpec      SIGNED
# 23     211470  777900            CleanPack      SIGNED
# 24     208925  747461  Robust OTFT sensors      SIGNED
# 25     211132  767609         SMART BIKING      SIGNED
# 26     208830  739638            WILDBERRY      SIGNED
# 27     210040  739754       MyTherapyTools  TERMINATED
# 28     208684  750294             NAPANODE  TERMINATED
# 29     208465  724508           RESISTANCE      SIGNED
# ...       ...     ...                  ...         ...
# 20484  205171  675087                AMBER      SIGNED
# 20485  193202  633281    FAWORIT 2014-2015      SIGNED
# 20486  211516  779071               SwiftC      SIGNED
# 20487  212621  746908           ORI NUMBER      SIGNED
# 20488  212636  749591             MECODIHR      SIGNED
# 20489  193181  633172              EuroMix      SIGNED
# 20490  193204  633292     DiscoverResearch      SIGNED
# 20491  205225  703570               INVeST      SIGNED
# 20492  205219  702004     Operation Condor      SIGNED
# 20493  205176  678889            CLIMASLOW      SIGNED
# 20494  204713  679614              BROKERS      SIGNED
# 20495  204704  678578                HRMEG      SIGNED
# 20496  200701  677650                 ARCA      SIGNED
# 20497  200699  677576              HARVEST      SIGNED
# 20498  210044  740477               SAURON      SIGNED
# 20499  205172  675324               ENRICH      SIGNED
# 20500  205187  682512              OXYFLUX      SIGNED
# 20501  205174  675662                QCALL      SIGNED
# 20502  205185  681978             Brain3.0      SIGNED
# 20503  205178  680200          MYELOMANEXT      SIGNED
# 20504  205169  653718                 ENOS      SIGNED
# 20505  205188  682574            ASSIMILES      SIGNED
# 20506  205196  693124                ONOFF      SIGNED
# 20507  205213  700108           BORONDYKAT      SIGNED
# 20508  214359  772103             BRIDGING      SIGNED
# 20509  214317  798326             AXO-MATH      SIGNED
# 20510  205180  681295              BactInd      SIGNED
# 20511  205207  695136         Secret-Cells      SIGNED
# 20512  205186  682022              MEDIATE      SIGNED
# 20513  205195  693039          Sphingolead      SIGNED
#
#                                                programme  \
# 0                   [H2020-EU.2.1.3., H2020-EU.2.1.5.1.]
# 1                   [H2020-EU.2.1.3., H2020-EU.2.1.5.1.]
# 2            [H2020-EU.3., H2020-EU.2.3., H2020-EU.2.1.]
# 3                                    [H2020-EU.3.6.2.1.]
# 4                                    [H2020-EU.3.6.2.1.]
# 5                                    [H2020-EU.3.6.2.1.]
# 6            [H2020-EU.3., H2020-EU.2.3., H2020-EU.2.1.]
# 7            [H2020-EU.3., H2020-EU.2.3., H2020-EU.2.1.]
# 8                                      [H2020-EU.2.1.1.]
# 9                                      [H2020-EU.1.2.2.]
# 10                                     [H2020-EU.1.3.2.]
# 11                    [H2020-EU.2.1.1., H2020-EU.2.3.1.]
# 12                    [H2020-EU.2.1.1., H2020-EU.2.3.1.]
# 13     [H2020-EU.3.1.4., H2020-EU.2.1.1., H2020-EU.2....
# 14     [H2020-EU.3.3., H2020-EU.2.1.1., H2020-EU.2.3.1.]
# 15                    [H2020-EU.2.1.6., H2020-EU.2.3.1.]
# 16     [H2020-EU.3.4., H2020-EU.2.1.1., H2020-EU.2.3.1.]
# 17                    [H2020-EU.2.1.1., H2020-EU.2.3.1.]
# 18                                     [H2020-EU.2.1.1.]
# 19                      [H2020-EU.3.5., H2020-EU.2.3.1.]
# 20                                     [H2020-EU.2.1.1.]
# 21     [H2020-EU.3.1.4., H2020-EU.2.1.1., H2020-EU.2....
# 22                            [H2020-EU.3., H2020-EU.2.]
# 23     [H2020-EU.3.2.4., H2020-EU.3.2.1., H2020-EU.2....
# 24                                     [H2020-EU.1.3.2.]
# 25     [H2020-EU.3.4., H2020-EU.2.1.1., H2020-EU.2.3.1.]
# 26                                   [H2020-EU.2.3.2.2.]
# 27                                   [H2020-EU.2.3.2.2.]
# 28                                     [H2020-EU.1.3.2.]
# 29                                       [H2020-EU.1.1.]
# ...                                                  ...
# 20484                                  [H2020-EU.1.3.1.]
# 20485                                  [H2020-EU.1.3.5.]
# 20486                   [H2020-EU.3.6., H2020-EU.2.3.1.]
# 20487                                  [H2020-EU.1.3.2.]
# 20488                                  [H2020-EU.1.3.2.]
# 20489                                    [H2020-EU.3.2.]
# 20490                                  [H2020-EU.1.3.5.]
# 20491                                  [H2020-EU.1.3.2.]
# 20492                                  [H2020-EU.1.3.2.]
# 20493                                    [H2020-EU.1.1.]
# 20494                                    [H2020-EU.1.1.]
# 20495                                    [H2020-EU.1.1.]
# 20496                                    [H2020-EU.1.1.]
# 20497                                    [H2020-EU.1.1.]
# 20498                 [H2020-EU.3.7.4., H2020-EU.3.7.2.]
# 20499                                  [H2020-EU.1.3.1.]
# 20500                                    [H2020-EU.1.1.]
# 20501                                  [H2020-EU.1.3.1.]
# 20502                                    [H2020-EU.1.1.]
# 20503                                    [H2020-EU.1.1.]
# 20504                                [H2020-EU.3.3.2.3.]
# 20505                                    [H2020-EU.1.1.]
# 20506                                    [H2020-EU.1.1.]
# 20507                                  [H2020-EU.1.3.2.]
# 20508                                    [H2020-EU.1.1.]
# 20509                                  [H2020-EU.1.3.2.]
# 20510                                    [H2020-EU.1.1.]
# 20511                                    [H2020-EU.1.1.]
# 20512                                    [H2020-EU.1.1.]
# 20513                                    [H2020-EU.1.1.]
#
#                         topics frameworkProgramme  \
# 0              DT-NMBP-20-2018              H2020
# 1              DT-NMBP-20-2018              H2020
# 2        EIC-SMEInst-2018-2020              H2020
# 3           IBA-SC6-Nexus-2017              H2020
# 4         IBA-SC6-AUSTRIA-2018              H2020
# 5      IBA-SC6-Industrial-2017              H2020
# 6        EIC-SMEInst-2018-2020              H2020
# 7        EIC-SMEInst-2018-2020              H2020
# 8                  ICT-08-2017              H2020
# 9               FETHPC-02-2017              H2020
# 10                MSCA-IF-2016              H2020
# 11        SMEInst-01-2016-2017              H2020
# 12        SMEInst-01-2016-2017              H2020
# 13        SMEInst-06-2016-2017              H2020
# 14        SMEInst-09-2016-2017              H2020
# 15        SMEInst-04-2016-2017              H2020
# 16        SMEInst-10-2016-2017              H2020
# 17        SMEInst-01-2016-2017              H2020
# 18                 ICT-08-2017              H2020
# 19        SMEInst-11-2016-2017              H2020
# 20                 ICT-08-2017              H2020
# 21        SMEInst-06-2016-2017              H2020
# 22            FTIPilot-01-2016              H2020
# 23        SMEInst-07-2016-2017              H2020
# 24                MSCA-IF-2016              H2020
# 25        SMEInst-10-2016-2017              H2020
# 26             INNOSUP-02-2016              H2020
# 27             INNOSUP-02-2016              H2020
# 28                MSCA-IF-2016              H2020
# 29                ERC-2016-COG              H2020
# ...                        ...                ...
# 20484        MSCA-ITN-2015-ETN              H2020
# 20485          MSCA-NIGHT-2014              H2020
# 20486     SMEInst-12-2016-2017              H2020
# 20487             MSCA-IF-2016              H2020
# 20488             MSCA-IF-2016              H2020
# 20489              SFS-12-2014              H2020
# 20490          MSCA-NIGHT-2014              H2020
# 20491          MSCA-IF-2015-EF              H2020
# 20492          MSCA-IF-2015-GF              H2020
# 20493             ERC-StG-2015              H2020
# 20494             ERC-StG-2015              H2020
# 20495             ERC-StG-2015              H2020
# 20496             ERC-StG-2015              H2020
# 20497             ERC-StG-2015              H2020
# 20498         CIP-01-2016-2017              H2020
# 20499        MSCA-ITN-2015-ETN              H2020
# 20500             ERC-CoG-2015              H2020
# 20501        MSCA-ITN-2015-ETN              H2020
# 20502             ERC-CoG-2015              H2020
# 20503             ERC-StG-2015              H2020
# 20504              LCE-15-2015              H2020
# 20505             ERC-CoG-2015              H2020
# 20506             ERC-ADG-2015              H2020
# 20507          MSCA-IF-2015-EF              H2020
# 20508             ERC-2017-COG              H2020
# 20509             MSCA-IF-2017              H2020
# 20510             ERC-CoG-2015              H2020
# 20511             ERC-ADG-2015              H2020
# 20512             ERC-CoG-2015              H2020
# 20513             ERC-PoC-2015              H2020
#
#                                                    title  startDate  \
# 0      Digital Dynamic Knowledge Platform for Welding... 2018-10-01
# 1      A Multi-Sided Business Platform for Plug and P... 2018-11-01
# 2      High-resolution, all-digital microscope that a... 2018-05-01
# 3      Microdata analysis for Policies for Productivi... 2018-07-01
# 4      Conference on the âImpact of Social Sciences... 2018-03-01
# 5       Global Industrial Research & Innovation Analyses 2018-06-01
# 6      EndodrillÂ® Model X - a new endoscopic biopsy ... 2018-03-01
# 7      Automatic Hitching for total Safety of Farmers... 2018-05-01
# 8                                                 5GCITY 2017-06-01
# 9      European joint Effort toward a Highly Producti... 2018-10-01
# 10     Functional exploration of the contributions of... 2018-01-01
# 11     Fast IoT market take-up through The Things Net... 2018-02-01
# 12     The most cost-efficient video ad creation plat... 2017-10-01
# 13     Affordable, accessible and automatic screening... 2017-08-01
# 14     High-capacity and high-performance Thermal ene... 2017-08-01
# 15     Securing water for food and safety with the wo... 2017-10-01
# 16     SIADE SaaS: Spatial Decision Support System fo... 2017-09-01
# 17     Delivering contextual information in a hands-f... 2017-09-01
# 18                 Next Generation Platform as a Service 2017-06-01
# 19      Turning food industry's organic wastw into value 2017-08-01
# 20     5G Development and validation platform for glo... 2017-06-01
# 21                         Hack your Diabetes Experience 2017-07-01
# 22     A rapid, non-invasive, cost-effective, analyti... 2017-05-01
# 23     UltraCLEAN thermoforming equipment for food PA... 2017-08-01
# 24     Ultra-robust, flexible organic sensors for app... 2017-07-01
# 25                      Safe parking system for bicycles 2017-07-01
# 26     Novel application targets and products derived... 2017-09-01
# 27     SME Innovation Associate: matching MyTherapyTo... 2018-03-01
# 28     Molecular Foundation of Structural and Dynamic... 2017-03-01
# 29     Resistance evolution in response to spatially ... 2017-03-01
# ...                                                  ...        ...
# 20484                 AMBER - enhAnced Mobile BiomEtRics 2017-01-01
# 20485  Looking over the Horizon - horizontal prioriti... 2014-05-01
# 20486  A technology marketplace for hospitality compl... 2017-09-01
# 20487  Unravelling the effect of origin number on the... 2017-12-01
# 20488  MEchanisms of Coupling of Ocean Dynamics and I... 2018-10-01
# 20489                                            EuroMix 2015-05-15
# 20490  Discover Research Dublin - European Researcher... 2014-06-01
# 20491  INdividual Vascular SignaTure: A new machine l... 2016-09-01
# 20492  Operation Condor: Accountability for Transnati... 2016-08-01
# 20493  Slowing Down Climate Change: Combining Climate... 2017-01-01
# 20494  Participatory Urban Governance between Democra... 2016-08-01
# 20495  HRMEG: High-resolution magnetoencephalography:... 2016-09-01
# 20496  Analysis and Representation of Complex Activit... 2016-06-01
# 20497  Plant foods in human evolution: Factors affect... 2017-02-01
# 20498  Scalable multidimensionAl sitUation awaReness ... 2017-05-01
# 20499         Enriched communication across the lifespan 2016-10-01
# 20500  Oxygen flux measurements as a new tracer for t... 2016-10-01
# 20501                     Quantum Communications for ALL 2016-12-01
# 20502  Invasive cognitive brain computer interfaces t... 2016-10-01
# 20503  Integrated next-generation flow cytometry and ... 2016-09-01
# 20504             ENabling Onshore CO2 Storage in Europe 2016-09-01
# 20505  Advanced Spectroscopy and Spectrometry for Ima... 2016-09-01
# 20506  Perception of voices that do not exist: Tracki... 2016-09-01
# 20507  VINYL AND HETEROARYL BORONIC ACIDS AS NON-STAB... 2016-08-01
# 20508  The function of membrane tethering in plant in... 2018-06-01
# 20509  Imaging and analyzing dynamics of reward-relat... 2018-05-01
# 20510  Bacterial cooperation at the individual cell l... 2016-09-01
# 20511  Cellular diversity and stress-induced cell-sta... 2016-09-01
# 20512  Middlebrow Enlightenment: Disseminating Ideas,... 2016-09-01
# 20513  Development of a potent dual GCS/GBA2 inhibito... 2016-09-01
#
#          endDate   ...    fundingScheme  \
# 0     2022-03-31   ...            IA-LS
# 1     2022-04-30   ...            IA-LS
# 2     2018-08-31   ...            SME-1
# 3     2021-06-30   ...              CSA
# 4     2019-02-28   ...              CSA
# 5     2020-11-30   ...              CSA
# 6     2018-08-31   ...            SME-1
# 7     2018-08-31   ...            SME-1
# 8     2019-11-30   ...               IA
# 9     2021-09-30   ...              RIA
# 10    2019-12-31   ...    MSCA-IF-EF-ST
# 11    2018-07-31   ...            SME-1
# 12    2019-03-31   ...            SME-2
# 13    2019-07-31   ...            SME-2
# 14    2019-07-31   ...            SME-2
# 15    2019-03-31   ...            SME-2
# 16    2019-08-31   ...            SME-2
# 17    2019-08-31   ...            SME-2
# 18    2019-05-31   ...               IA
# 19    2019-07-31   ...            SME-2
# 20    2019-11-30   ...               IA
# 21    2019-06-30   ...            SME-2
# 22    2019-04-30   ...               IA
# 23    2019-07-31   ...            SME-2
# 24    2019-06-30   ...       MSCA-IF-GF
# 25    2019-06-30   ...            SME-2
# 26    2018-08-31   ...              CSA
# 27    2019-02-28   ...              CSA
# 28    2019-02-28   ...    MSCA-IF-EF-ST
# 29    2022-02-28   ...          ERC-COG
# ...          ...   ...              ...
# 20484 2020-12-31   ...     MSCA-ITN-ETN
# 20485 2015-11-30   ...              CSA
# 20486 2019-08-31   ...            SME-2
# 20487 2019-11-30   ...    MSCA-IF-EF-ST
# 20488 2021-09-30   ...       MSCA-IF-GF
# 20489 2019-05-14   ...              RIA
# 20490 2015-11-30   ...              CSA
# 20491 2018-08-31   ...    MSCA-IF-EF-ST
# 20492 2019-07-31   ...       MSCA-IF-GF
# 20493 2021-12-31   ...          ERC-STG
# 20494 2021-07-31   ...          ERC-STG
# 20495 2021-08-31   ...          ERC-STG
# 20496 2021-05-31   ...          ERC-STG
# 20497 2022-01-31   ...          ERC-STG
# 20498 2020-04-30   ...               IA
# 20499 2020-09-30   ...     MSCA-ITN-ETN
# 20500 2021-09-30   ...          ERC-COG
# 20501 2020-11-30   ...     MSCA-ITN-ETN
# 20502 2021-09-30   ...          ERC-COG
# 20503 2021-08-31   ...          ERC-STG
# 20504 2020-08-31   ...              RIA
# 20505 2021-08-31   ...          ERC-COG
# 20506 2021-08-31   ...          ERC-ADG
# 20507 2018-07-31   ...    MSCA-IF-EF-ST
# 20508 2023-05-31   ...          ERC-COG
# 20509 2020-04-30   ...    MSCA-IF-EF-ST
# 20510 2021-08-31   ...          ERC-COG
# 20511 2021-08-31   ...          ERC-ADG
# 20512 2021-08-31   ...          ERC-COG
# 20513 2018-02-28   ...          ERC-POC
#
#                                              coordinator  coordinatorCountry  \
# 0                                            TWI LIMITED                  UK
# 1                             INTRASOFT INTERNATIONAL SA                  BE
# 2                                        SCOPIO LABS LTD                  IL
# 3      ORGANISATION FOR ECONOMIC CO-OPERATION AND DEV...                  FR
# 4                    ZENTRUM FUR SOZIALE INNOVATION GMBH                  AT
# 5        JRC -JOINT RESEARCH CENTRE- EUROPEAN COMMISSION                  BE
# 6                                     BIBBINSTRUMENTS AB                  SE
# 7                                      SIWI MASKINER APS                  DK
# 8      FUNDACIO PRIVADA I2CAT, INTERNET I INNOVACIO D...                  ES
# 9      BARCELONA SUPERCOMPUTING CENTER - CENTRO NACIO...                  ES
# 10     FRIEDRICH MIESCHER INSTITUTE FOR BIOMEDICAL RE...                  CH
# 11                              THE THINGS INDUSTRIES BV                  NL
# 12                                  NEXTCHANCE ASSETS SL                  ES
# 13                                            OPTOMED OY                  FI
# 14                                 ESDA TECHNOLOGIE GMBH                  DE
# 15                                          VANDERSAT BV                  NL
# 16                               TERRAIN TECHNOLOGIES SL                  ES
# 17                                           GLASSUP SRL                  IT
# 18                                NOKIA BELL LABS FRANCE                  FR
# 19                                        HOMEBIOGAS LTD                  IL
# 20                                         ATOS SPAIN SA                  ES
# 21                                     SOCIALDIABETES SL                  ES
# 22                            IMSPEX DIAGNOSTICS LIMITED                  UK
# 23                                           TECSELOR SL                  ES
# 24     THE CHANCELLOR MASTERS AND SCHOLARS OF THE UNI...                  UK
# 25                                           VADECITY SL                  ES
# 26                                              EXTRX OY                  FI
# 27                                   MY THERAPY TOOLS SL                  ES
# 28     THE CHANCELLOR MASTERS AND SCHOLARS OF THE UNI...                  UK
# 29                                   HELSINGIN YLIOPISTO                  FI
# ...                                                  ...                 ...
# 20484                                 UNIVERSITY OF KENT                  UK
# 20485  BAY ZOLTAN ALKALMAZOTT KUTATASI KOZHASZNU NONP...                  HU
# 20486                              SWIFTCOMPLY TOPCO LTD                  IE
# 20487                               UNIVERSITY OF DUNDEE                  UK
# 20488                 UNIVERSITE DE BRETAGNE OCCIDENTALE                  FR
# 20489      RIJKSINSTITUUT VOOR VOLKSGEZONDHEID EN MILIEU                  NL
# 20490  THE PROVOST, FELLOWS, FOUNDATION SCHOLARS & TH...                  IE
# 20491                                   ASTON UNIVERSITY                  UK
# 20492  THE CHANCELLOR, MASTERS AND SCHOLARS OF THE UN...                  UK
# 20493                               ITA-SUOMEN YLIOPISTO                  FI
# 20494                  STICHTING KATHOLIEKE UNIVERSITEIT                  NL
# 20495                         AALTO KORKEAKOULUSAATIO SR                  FI
# 20496     RHEINISCHE FRIEDRICH-WILHELMS-UNIVERSITAT BONN                  DE
# 20497                                UNIVERSITEIT LEIDEN                  NL
# 20498  FUNDACION DE LA COMUNIDAD VALENCIANA PARA LA I...                  ES
# 20499  UNIVERSIDAD DEL PAIS VASCO/ EUSKAL HERRIKO UNI...                  ES
# 20500  GEORG-AUGUST-UNIVERSITAT GOTTINGENSTIFTUNG OFF...                  DE
# 20501                                UNIVERSITY OF LEEDS                  UK
# 20502  CENTRE NATIONAL DE LA RECHERCHE SCIENTIFIQUE CNRS                  FR
# 20503                             UNIVERSIDAD DE NAVARRA                  ES
# 20504       BUREAU DE RECHERCHES GEOLOGIQUES ET MINIERES                  FR
# 20505  THE CHANCELLOR MASTERS AND SCHOLARS OF THE UNI...                  UK
# 20506                             UNIVERSITETET I BERGEN                  NO
# 20507  THE CHANCELLOR, MASTERS AND SCHOLARS OF THE UN...                  UK
# 20508  CENTRE NATIONAL DE LA RECHERCHE SCIENTIFIQUE CNRS                  FR
# 20509  CENTRE NATIONAL DE LA RECHERCHE SCIENTIFIQUE CNRS                  FR
# 20510                                 UNIVERSITAT ZURICH                  CH
# 20511                     MEDIZINISCHE UNIVERSITAET WIEN                  AT
# 20512                  STICHTING KATHOLIEKE UNIVERSITEIT                  NL
# 20513                                UNIVERSITEIT LEIDEN                  NL
#
#                                             participants  \
# 0      [LULEA TEKNISKA UNIVERSITET, ROMSOFT SRL, TECH...
# 1      [N.BAZIGOS ABEE, NEDERLANDSE ORGANISATIE VOOR ...
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# 5                                                    NaN
# 6                                                    NaN
# 7                                                    NaN
# 8      [COMUNICARE DIGITALE - ASSOCIAZIONEDI PROMOZIO...
# 9      [INSTITUT NATIONAL DE RECHERCHE ENINFORMATIQUE...
# 10                                                   NaN
# 11                                                   NaN
# 12                                                   NaN
# 13                                                   NaN
# 14                                                   NaN
# 15                                                   NaN
# 16                                                   NaN
# 17                                                   NaN
# 18     [B-COM, ORANGE SA, INTERUNIVERSITAIR MICRO-ELE...
# 19                                                   NaN
# 20     [NUROGAMES GMBH, CENTRE TECNOLOGIC DE TELECOMU...
# 21                                                   NaN
# 22     [REDKNIGHT CONSULTANCY LTD, THE UNIVERSITY OF ...
# 23                                                   NaN
# 24                                                   NaN
# 25                                                   NaN
# 26                                                   NaN
# 27                                                   NaN
# 28                                                   NaN
# 29                                                   NaN
# ...                                                  ...
# 20484  [OTTO-VON-GUERICKE-UNIVERSITAET MAGDEBURG, UNI...
# 20485  [TUDOMANYOS ISMERETTERJESZTO TARSULAT, REGIONA...
# 20486                                                NaN
# 20487                                                NaN
# 20488                                                NaN
# 20489  [STATNI ZDRAVOTNI USTAV, UNIVERSITAT ROVIRA I ...
# 20490                                                NaN
# 20491                                                NaN
# 20492                                                NaN
# 20493                                                NaN
# 20494                                                NaN
# 20495                                                NaN
# 20496                                                NaN
# 20497  [MAX-PLANCK-GESELLSCHAFT ZUR FORDERUNG DER WIS...
# 20498  [IDEMIA IDENTITY & SECURITY FRANCE, INNOVASEC ...
# 20499  [STICHTING KATHOLIEKE UNIVERSITEIT, FRAUNHOFER...
# 20500                        [UNIVERSITY OF EAST ANGLIA]
# 20501  [UNIVERSITE PIERRE ET MARIE CURIE - PARIS 6, H...
# 20502                                                NaN
# 20503                                                NaN
# 20504  [FLODIM SARL, NHAZCA SRL, NEDERLANDSE ORGANISA...
# 20505                                                NaN
# 20506                                                NaN
# 20507                                                NaN
# 20508                                                NaN
# 20509                                                NaN
# 20510                                                NaN
# 20511                                                NaN
# 20512                                                NaN
# 20513                                                NaN
#
#                                     participantCountries subjects  \
# 0                       [SE, RO, UK, NO, PL, FR, IL, ES]      NaN
# 1                   [EL, NL, ES, DE, IT, FR, AT, LU, LT]      NaN
# 2                                                    NaN      NaN
# 3                                                    NaN      NaN
# 4                                                    NaN      NaN
# 5                                                    NaN      NaN
# 6                                                    NaN      NaN
# 7                                                    NaN      NaN
# 8                       [IT, ES, FR, BE, DE, UK, LU, PT]      NaN
# 9                           [FR, SE, DE, BE, ES, PT, IT]      NaN
# 10                                                   NaN      NaN
# 11                                                   NaN      NaN
# 12                                                   NaN      NaN
# 13                                                   NaN      NaN
# 14                                                   NaN      NaN
# 15                                                   NaN      NaN
# 16                                                   NaN      NaN
# 17                                                   NaN      NaN
# 18                      [FR, BE, ES, GI, DK, UK, IT, IL]      NaN
# 19                                                   NaN      NaN
# 20                  [DE, ES, BE, EL, IE, PT, CY, UK, FR]      NaN
# 21                                                   NaN      NaN
# 22                                          [UK, IE, DE]      NaN
# 23                                                   NaN      NaN
# 24                                                   NaN      NaN
# 25                                                   NaN      NaN
# 26                                                   NaN      NaN
# 27                                                   NaN      NaN
# 28                                                   NaN      NaN
# 29                                                   NaN      NaN
# ...                                                  ...      ...
# 20484                                   [DE, IT, PL, ES]      NaN
# 20485                                               [HU]      NaN
# 20486                                                NaN      NaN
# 20487                                                NaN      NaN
# 20488                                                NaN      NaN
# 20489  [CZ, ES, DE, NO, UK, BE, SI, FR, IS, EL, CH, C...      NaN
# 20490                                                NaN      NaN
# 20491                                                NaN      NaN
# 20492                                                NaN      NaN
# 20493                                                NaN      NaN
# 20494                                                NaN      NaN
# 20495                                                NaN      NaN
# 20496                                                NaN      NaN
# 20497                                               [DE]      NaN
# 20498                   [FR, UK, AT, IT, SI, EL, ES, BE]      NaN
# 20499                               [NL, DE, SE, EL, UK]      NaN
# 20500                                               [UK]      NaN
# 20501                           [FR, DE, CH, IT, UK, ES]      NaN
# 20502                                                NaN      NaN
# 20503                                                NaN      NaN
# 20504               [FR, IT, NL, DE, NO, ES, UK, SK, CZ]      NaN
# 20505                                                NaN      NaN
# 20506                                                NaN      NaN
# 20507                                                NaN      NaN
# 20508                                                NaN      NaN
# 20509                                                NaN      NaN
# 20510                                                NaN      NaN
# 20511                                                NaN      NaN
# 20512                                                NaN      NaN
# 20513                                                NaN      NaN
#
#                                            organisations  \
# 0      [TWI LIMITED, LULEA TEKNISKA UNIVERSITET, ROMS...
# 1      [INTRASOFT INTERNATIONAL SA, N.BAZIGOS ABEE, N...
# 2                                      [SCOPIO LABS LTD]
# 3      [ORGANISATION FOR ECONOMIC CO-OPERATION AND DE...
# 4                  [ZENTRUM FUR SOZIALE INNOVATION GMBH]
# 5      [JRC -JOINT RESEARCH CENTRE- EUROPEAN COMMISSION]
# 6                                   [BIBBINSTRUMENTS AB]
# 7                                    [SIWI MASKINER APS]
# 8      [FUNDACIO PRIVADA I2CAT, INTERNET I INNOVACIO ...
# 9      [BARCELONA SUPERCOMPUTING CENTER - CENTRO NACI...
# 10     [FRIEDRICH MIESCHER INSTITUTE FOR BIOMEDICAL R...
# 11                            [THE THINGS INDUSTRIES BV]
# 12                                [NEXTCHANCE ASSETS SL]
# 13                                          [OPTOMED OY]
# 14                               [ESDA TECHNOLOGIE GMBH]
# 15                                        [VANDERSAT BV]
# 16                             [TERRAIN TECHNOLOGIES SL]
# 17                                         [GLASSUP SRL]
# 18     [NOKIA BELL LABS FRANCE, B-COM, ORANGE SA, INT...
# 19                                      [HOMEBIOGAS LTD]
# 20     [ATOS SPAIN SA, NUROGAMES GMBH, CENTRE TECNOLO...
# 21                                   [SOCIALDIABETES SL]
# 22     [IMSPEX DIAGNOSTICS LIMITED, REDKNIGHT CONSULT...
# 23                                         [TECSELOR SL]
# 24     [THE CHANCELLOR MASTERS AND SCHOLARS OF THE UN...
# 25                                         [VADECITY SL]
# 26                                            [EXTRX OY]
# 27                                 [MY THERAPY TOOLS SL]
# 28     [THE CHANCELLOR MASTERS AND SCHOLARS OF THE UN...
# 29                                 [HELSINGIN YLIOPISTO]
# ...                                                  ...
# 20484  [UNIVERSITY OF KENT, OTTO-VON-GUERICKE-UNIVERS...
# 20485  [BAY ZOLTAN ALKALMAZOTT KUTATASI KOZHASZNU NON...
# 20486                            [SWIFTCOMPLY TOPCO LTD]
# 20487                             [UNIVERSITY OF DUNDEE]
# 20488               [UNIVERSITE DE BRETAGNE OCCIDENTALE]
# 20489  [RIJKSINSTITUUT VOOR VOLKSGEZONDHEID EN MILIEU...
# 20490  [THE PROVOST, FELLOWS, FOUNDATION SCHOLARS & T...
# 20491                                 [ASTON UNIVERSITY]
# 20492  [THE CHANCELLOR, MASTERS AND SCHOLARS OF THE U...
# 20493                             [ITA-SUOMEN YLIOPISTO]
# 20494                [STICHTING KATHOLIEKE UNIVERSITEIT]
# 20495                       [AALTO KORKEAKOULUSAATIO SR]
# 20496   [RHEINISCHE FRIEDRICH-WILHELMS-UNIVERSITAT BONN]
# 20497  [UNIVERSITEIT LEIDEN, MAX-PLANCK-GESELLSCHAFT ...
# 20498  [FUNDACION DE LA COMUNIDAD VALENCIANA PARA LA ...
# 20499  [UNIVERSIDAD DEL PAIS VASCO/ EUSKAL HERRIKO UN...
# 20500  [GEORG-AUGUST-UNIVERSITAT GOTTINGENSTIFTUNG OF...
# 20501  [UNIVERSITY OF LEEDS, UNIVERSITE PIERRE ET MAR...
# 20502  [CENTRE NATIONAL DE LA RECHERCHE SCIENTIFIQUE ...
# 20503                           [UNIVERSIDAD DE NAVARRA]
# 20504  [BUREAU DE RECHERCHES GEOLOGIQUES ET MINIERES,...
# 20505  [THE CHANCELLOR MASTERS AND SCHOLARS OF THE UN...
# 20506                           [UNIVERSITETET I BERGEN]
# 20507  [THE CHANCELLOR, MASTERS AND SCHOLARS OF THE U...
# 20508  [CENTRE NATIONAL DE LA RECHERCHE SCIENTIFIQUE ...
# 20509  [CENTRE NATIONAL DE LA RECHERCHE SCIENTIFIQUE ...
# 20510                               [UNIVERSITAT ZURICH]
# 20511                   [MEDIZINISCHE UNIVERSITAET WIEN]
# 20512                [STICHTING KATHOLIEKE UNIVERSITEIT]
# 20513                              [UNIVERSITEIT LEIDEN]
#
#                                                countries startYear endYear
# 0                   [UK, SE, RO, UK, NO, PL, FR, IL, ES]    2018.0  2022.0
# 1               [BE, EL, NL, ES, DE, IT, FR, AT, LU, LT]    2018.0  2022.0
# 2                                                   [IL]    2018.0  2018.0
# 3                                                   [FR]    2018.0  2021.0
# 4                                                   [AT]    2018.0  2019.0
# 5                                                   [BE]    2018.0  2020.0
# 6                                                   [SE]    2018.0  2018.0
# 7                                                   [DK]    2018.0  2018.0
# 8                   [ES, IT, ES, FR, BE, DE, UK, LU, PT]    2017.0  2019.0
# 9                       [ES, FR, SE, DE, BE, ES, PT, IT]    2018.0  2021.0
# 10                                                  [CH]    2018.0  2019.0
# 11                                                  [NL]    2018.0  2018.0
# 12                                                  [ES]    2017.0  2019.0
# 13                                                  [FI]    2017.0  2019.0
# 14                                                  [DE]    2017.0  2019.0
# 15                                                  [NL]    2017.0  2019.0
# 16                                                  [ES]    2017.0  2019.0
# 17                                                  [IT]    2017.0  2019.0
# 18                  [FR, FR, BE, ES, GI, DK, UK, IT, IL]    2017.0  2019.0
# 19                                                  [IL]    2017.0  2019.0
# 20              [ES, DE, ES, BE, EL, IE, PT, CY, UK, FR]    2017.0  2019.0
# 21                                                  [ES]    2017.0  2019.0
# 22                                      [UK, UK, IE, DE]    2017.0  2019.0
# 23                                                  [ES]    2017.0  2019.0
# 24                                                  [UK]    2017.0  2019.0
# 25                                                  [ES]    2017.0  2019.0
# 26                                                  [FI]    2017.0  2018.0
# 27                                                  [ES]    2018.0  2019.0
# 28                                                  [UK]    2017.0  2019.0
# 29                                                  [FI]    2017.0  2022.0
# ...                                                  ...       ...     ...
# 20484                               [UK, DE, IT, PL, ES]    2017.0  2020.0
# 20485                                           [HU, HU]    2014.0  2015.0
# 20486                                               [IE]    2017.0  2019.0
# 20487                                               [UK]    2017.0  2019.0
# 20488                                               [FR]    2018.0  2021.0
# 20489  [NL, CZ, ES, DE, NO, UK, BE, SI, FR, IS, EL, C...    2015.0  2019.0
# 20490                                               [IE]    2014.0  2015.0
# 20491                                               [UK]    2016.0  2018.0
# 20492                                               [UK]    2016.0  2019.0
# 20493                                               [FI]    2017.0  2021.0
# 20494                                               [NL]    2016.0  2021.0
# 20495                                               [FI]    2016.0  2021.0
# 20496                                               [DE]    2016.0  2021.0
# 20497                                           [NL, DE]    2017.0  2022.0
# 20498               [ES, FR, UK, AT, IT, SI, EL, ES, BE]    2017.0  2020.0
# 20499                           [ES, NL, DE, SE, EL, UK]    2016.0  2020.0
# 20500                                           [DE, UK]    2016.0  2021.0
# 20501                       [UK, FR, DE, CH, IT, UK, ES]    2016.0  2020.0
# 20502                                               [FR]    2016.0  2021.0
# 20503                                               [ES]    2016.0  2021.0
# 20504           [FR, FR, IT, NL, DE, NO, ES, UK, SK, CZ]    2016.0  2020.0
# 20505                                               [UK]    2016.0  2021.0
# 20506                                               [NO]    2016.0  2021.0
# 20507                                               [UK]    2016.0  2018.0
# 20508                                               [FR]    2018.0  2023.0
# 20509                                               [FR]    2018.0  2020.0
# 20510                                               [CH]    2016.0  2021.0
# 20511                                               [AT]    2016.0  2021.0
# 20512                                               [NL]    2016.0  2021.0
# 20513                                               [NL]    2016.0  2018.0
#
# [20514 rows x 25 columns]

# %%
# for example, the first row 
print(cordis_projects_df['startDate'][0].year)
print(cordis_projects_df['startDate'][0].month)
print(cordis_projects_df['startDate'][0].day)
# Out:
# 2018
# 10
# 1

# %%
#use lambda to apply a method to each element row-wise if want to apply 
#can add 
cordis_projects_df['month'] = cordis_projects_df['startDate'].dt.month
cordis_projects_df['month'].head()
# Out:
# 0    10.0
# 1    11.0
# 2     5.0
# 3     7.0
# 4     3.0
# Name: month, dtype: float64

# %% [markdown]
# ## Strings

# %%
# can convert any column elements to string type .str

#.str.len()to get length of each string across 0

#.str.replace()

# %% [markdown]
# # Plotting

# %% [markdown]
# ## Pandas Plotting
# https://pandas.pydata.org/pandas-docs/stable/user_guide/visualization.html

# %%
#histogram plot - all pandas plota are matplotlib figs but are specifically pandas functions
cordis_projects_df['month'].hist()
# plt.show()

# %%
cordis_projects_df.columns

# %%
cordis_projects_df['totalCost'].plot(kind='bar')

# %%
# grouped_df.size().unstack().plot(kind= 'bar', stacked=True)

#show few examples directly from df

# %% [markdown]
# ## Plotting using MatplotLib
#
# https://matplotlib.org/3.1.1/contents.html

# %%
#to show they can be thrown into 
# one example with matplotlib

# %% [markdown]
# # Available Datasets

# %% [markdown]
# How to read these
